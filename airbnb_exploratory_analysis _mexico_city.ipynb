# %% [markdown]
# # **Explorando el Mercado de Airbnb en la Ciudad de México: Análisis de Tendencias y Factores Clave.**

# %% [markdown]
# ### **Table of Contents**

# %% [markdown]
# [1. Introduction](#introduction)
#
# [2. Project Description](#2-project-description)
#
# [3. Data Description](#3-data-description)
#
# [4. Import and Review Data](#4-import-and-review-data)
#
# [5. Basic Insight of Dataset](#5-basic-insight-of-dataset)
#
# [6. Data Wrangling](#6-data-wrangling)
#
# [7. Exploratory Data Analysis (EDA)](#7-exploratory-data-analysis-eda)
#
# - [Univariate Analysis of Price](#univariate-analysis-of-price)
# - [Categorical Data Analysis](#categorical-data-analysis)
# - [Numerical Data Analysis](#numerical-data-analysis)
#
# [8. Summary Analysis](#8-summary-analysis)
#
# [9. Conclusion](#9-conclusion)

# %% [markdown]
# ## Introduction

# %% [markdown]
# Desde 2008, huéspedes y anfitriones han utilizado Airbnb para ampliar las posibilidades de viaje y presentar una forma más única y personalizada de experimentar el mundo. Hoy en día, Airbnb se ha convertido en un servicio único utilizado y reconocido en todo el mundo. Este sistema es uno de los ejemplos de éxito más atractivos de la economía colaborativa, cuyo funcionamiento se resume en ser una plataforma intermediaria que contacta individuos que rentan una habitación, casa o departamento con usuarios que buscan un alojamiento turístico diferente al de un hotel.
#
# Un aspecto que le diferencia del hospedaje tradicional de los hoteles, es que ofrece diversas experiencias que involucran el contexto urbano en donde se ubique el alquiler, siendo la localización un factor importante a la hora de reservar. De esta forma Airbnb se ha expandido alrededor del mundo, en ciudades con atractivos turísticos cuyo desarrollo ha sido exponencial, siendo la CDMX uno de los mejores ejemplos a nivel internacional.
#
# Airbnb llegó a la CDMX en 2009 con poco menos de 11 listados en la plataforma, pero desde entonces el crecimiento ha sido exponencial. Airbnb ha crecido principalmente en las alcaldías con mayor oferta de servicios que son atractivos para el viajero. Actualmente, en CDMX hay cerca de 26,000 alojamientos incorporados a Airbnb. Principalmente, este crecimiento ha sido en zonas que por su naturaleza tienen mayor variedad de oferta cultural y turística, y que de alguna manera es más amigable para el turista.
#
# El análisis de datos de miles de listados ofertados a través de la plataforma de Airbnb es un factor crucial para comprender la dinámica y las tendencias del mercado de alojamiento en cualquier ciudad importante del mundo. Estos miles de listados generan una gran cantidad de datos: datos que pueden analizarse y usarse para seguridad, respaldar decisiones comerciales fundamentadas, comprender el comportamiento del mercado y evaluar el desempeño tanto de los clientes (huéspedes) como de los proveedores (anfitriones) en la plataforma. Además, estos datos pueden orientar iniciativas de marketing efectivas, respaldar la implementación de servicios adicionales innovadores y mucho más.

# %% [markdown]
# ## **2. Project Description**

# %% [markdown]
# Conocer el valor de mercado de una noche en un alojamiento de Airbnb y los factores que influyen en este, es de gran interés tanto para los anfitriones como para los huéspedes. Como huésped, uno puede sentirse un poco abrumado al ver todas las ofertas que ofrece Airbnb hoy en día (mas de 26,000 listados para la Ciudad de México en diciembre de 2023), conocer qué influye en los precios de los alojamientos y cómo varían los precios en relación a la zona geográfica podría hacer que todo el proceso de búsqueda sea más agradable. Por otro lado, fijar el precio adecuado es una tarea crucial para los anfitriones, para poder maximizar la ocupación de sus propiedades sin sacrificar la rentabilidad.
#
# Para abordar estas cuestiones, este proyecto tiene como objetivo identificar los factores clave que influyen en los precios de los alojamientos de Airbnb. Así como analizar e identificar tendencias y patrones en el mercado de alojamientos de la Ciudad de México. Para lograr esto, a lo largo del análisis se responderán las siguientes preguntas clave:
#
# - ***¿Cuál es la distribución de los diferentes tipos de alojamientos en la Ciudad de México?***
#
# - ***¿Cómo varía la distribución de precios de renta según las diferentes zonas geográficas de la ciudad?***
#
# - ***¿Cuál es la relación entre la ubicación geográfica y el tipo de alojamiento con el precio de renta?***
#
# - ***¿Qué impacto tienen la cantidad y la puntuación de las reseñas en el precio de renta de un alojamiento?***
#
# - ***¿Qué factores, como la ubicación, la calidad del alojamiento, las características del anfitrion y del alojamiento, entre otros, tienen mayor influencia en los precios de renta?***
#
# Se realizará un análisis descriptivo y exploratorio de los datos, con el fin de obtener y proporcionar insights valiosos que puedan ser útiles para los propietarios de alojamientos, inversores y cualquier persona interesada en el mercado de alojamientos en la Ciudad de México. Este análisis nos permitirá identificar qué características son más valoradas en los alojamientos, cómo varían los precios según la ubicación geográfica y otros factores relevantes que influyen en la dinámica del mercado de alojamientos en la ciudad.

# %% [markdown]
# ## **3. Data Description**
#
# La plataforma Airbnb solo proporciona una visión muy limitada de sus datos, pero un grupo separado llamado Inside Airbnb extrae y recopila información disponible públicamente sobre los listados de muchas ciudades del sitio web de Airbnb. Para este proyecto se analizaron datos de la Ciudad de México del año 2023 extraídos del sitio web de Inside Airbnb. Se puede acceder al conjunto de datos a través de este [enlace](https://insideairbnb.com/).
#
# El conjunto de datos incluye 26,760 listados de la Ciudad de México recopilados al 26 de diciembre de 2023. Cada fila del conjunto de datos es un listado disponible para alquiler en el sitio de Airbnb para la Ciudad de México (observaciones). Las columnas describen diferentes características de cada listado (atributos o variables). Algunas de las características más importantes que analizará este proyecto son las siguientes:
#
#
# - `neighbourhood`: la alcaldía donde está ubicado el alojamiento.
#
# - `room_type`: el tipo de alojamiento que se oferta.
#
# - `accommodates`: el número permitido de huéspedes que el alojamiento puede albergar.
#
# - `bedrooms`: número de habitaciones incluidas en el alojamiento.
#
# - `bathrooms`: el número de baños incluidos en el alojamiento.
#
# - `beds`: el número de camas incluidas en el alojamiento.
#
# - `price`: el precio por noche del alquiler.
#
# - `minimum_nights`: el mínimo número de noches que el huesped puede rentar el alojamiento.
#
# - `maximum_nights`: el máximo número de noches que el huesped puede rentar el alojamiento.
#
# - `number_of_reviews`: el número de reseñas que dejaron huéspedes anteriores.
#
# - `review_scores_rating`: la puntuación general de reseña del alojamiento.
#
#
# Como parte del proceso de preparación para este análisis, se realizó una limpieza previa de los datos en Excel. Durante esta etapa de limpieza previa se llevaron a cabo las siguientes acciones:
#
# * Se crearon variables nuevas sobre las características de los listados mediante la extracción de texto de otras columnas que contenían esta información.
# * Se eliminaron aquellas columnas que no eran relevantes para el análisis en cuestión, optimizando así la estructura del conjunto de datos.
# * Además, se aplicó un filtro para seleccionar únicamente los listados con al menos una reseña en los últimos 3 meses. Este criterio asegura que el análisis se realice con listados que estén activos y sean representativos del momento actual.

# %% [markdown]
# ## **4. Import and Review Data**

# %% [markdown]
# ### **Import Libraries**

# %% [markdown]
# En esta sección, se importan las librerías necesarias para el analisis y visualizacion de datos de este proyecto. Cada librería desempeña un papel importante en el proceso de análisis y nos proporciona herramientas y funciones específicas para manipular y representar los datos de manera efectiva. A continuación, se detallan las librerías importadas en este proyecto:
#
# - **pandas:** Utilizada para la manipulación y análisis de datos tabulares.
# - **numpy:** Proporciona funciones para realizar operaciones numéricas y matriciales en los datos.
# - **matplotlib.pyplot:** Utilizada para crear visualizaciones como gráficos de barras, líneas, histogramas, etc.
# - **seaborn:** Ofrece estilos adicionales y funcionalidades para mejorar las visualizaciones generadas con matplotlib.
# - **scipy.stats:** Proporciona herramientas estadísticas para realizar análisis más avanzados y pruebas de hipótesis.

# %%
# Importar librerías

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %% [markdown]
# ### **Read Data**

# %% [markdown]
# Luego de la importación de librerías, utilizamos el método `pd.read_csv()` de la biblioteca pandas para cargar el archivo CSV que contiene nuestros datos. Después de ejecutar este código, los datos del archivo CSV se cargarán en el DataFrame `df`, lo que nos permitirá utilizar las funcionalidades de pandas para analizar, manipular y visualizar los datos según sea necesario en nuestro proyecto de análisis de datos.

# %%
# Ruta del archivo

path = '../data/listings_precleaned.csv'

# %%
# Importar y crear DataFrame

df = pd.read_csv(path)

# %% [markdown]
#  A continuación, visualizamos brevemente la estructura del DataFrame recién creado para comprender la naturaleza y las características de los datos que vamos a analizar. Utilizamos la función `display()` para mostrar el DataFrame de una manera estructurada y legible, lo que facilita la identificación de las variables y sus respectivos valores. Por defecto se mostrarán las primeras 5 filas y las últimas 5 filas.

# %%
# Configurar pandas para mostrar todas las columnas sin truncar

pd.set_option('display.max_columns', None)

# %%
# Visualizar df

display(df)
# Out:
#                  id                                       listing_url  \
# 0      1.441434e+06              https://www.airbnb.com/rooms/1441434
# 1      1.462549e+06              https://www.airbnb.com/rooms/1462549
# 2      6.179200e+04                https://www.airbnb.com/rooms/61792
# 3      1.476127e+06              https://www.airbnb.com/rooms/1476127
# 4      6.770300e+04                https://www.airbnb.com/rooms/67703
# ...             ...                                               ...
# 16244  1.050000e+18  https://www.airbnb.com/rooms/1047985349007187163
# 16245  1.050000e+18  https://www.airbnb.com/rooms/1048570640617175411
# 16246  1.050000e+18  https://www.airbnb.com/rooms/1051715348642918854
# 16247  1.050000e+18  https://www.airbnb.com/rooms/1049340574001326246
# 16248  1.050000e+18  https://www.airbnb.com/rooms/1049580864703605137
#
#          host_id        host_name  host_since  host_response_time  \
# ...

# %% [markdown]
# ## **5. Basic Insight of Dataset**
#
# En esta sección, exploramos y obtenemos información básica sobre el conjunto de datos que estamos analizando. Utilizamos diversas técnicas y herramientas para adquirir una comprensión inicial de la estructura, características y distribución de los datos. Algunos de los aspectos que analizamos incluyen:
#
# - Dimensiones del dataset (número de filas y columnas).
# - Tipos de datos presentes en cada variable (numéricos, categóricos, fechas, etc.).
# - Información resumida del dataset
#
# Esta exploración inicial nos brindará una visión general del dataset para comprender su estructura, calidad y posibles desafíos que puedan surgir durante el análisis.

# %% [markdown]
# ### **Data Dimensions**

# %% [markdown]
# Primero exploramos las dimensiones del dataset, incluyendo el número de filas y columnas que lo componen. Esto nos brindará una comprensión inicial de la cantidad de datos disponibles y la estructura del dataset.

# %%
print(f"El dataset contiene {df.shape[0]} filas y {df.shape[1]} columnas.")
# Out:
# El dataset contiene 16249 filas y 34 columnas.

# %% [markdown]
# ### **Data Types**

# %% [markdown]
# Los datos tienen una variedad de tipos. Los principales tipos almacenados en los DataFrames de Pandas son `object`, `float`, `int`, `bool` y `datetime64`. Para conocer mejor cada variable, siempre es bueno que comprobemos el tipo de datos de cada columna. Hay dos razones para comprobar los tipos de datos en un conjunto de datos. La primera razón es que Pandas asigna automaticamente los tipos en función de la codificación que detecta en la tabla de datos original. Y por varios motivos, esta asignación puede ser incorrecta.
#
# La segunda razón es que nos permite a los analistas de datos ver qué funciones de Python se pueden aplicar a una columna específica. Por ejemplo, algunas funciones solo se pueden aplicar a datos numéricos, como cálculos matemáticos o estadísticos, mientras que otras funciones son específicas para texto o fechas. Al tener los tipos de datos correctamente asignados, podemos utilizar las funciones adecuadas para realizar análisis más precisos y detallados en nuestros datos.
#
# En Pandas, usamos `DataFrame.dtypes` para comprobar tipos de datos:

# %%
# Comprobar tipos de datos

df.dtypes
# Out:
# id                                float64
# listing_url                        object
# host_id                             int64
# host_name                          object
# host_since                         object
# host_response_time                 object
# host_response_rate                 object
# host_acceptance_rate               object
# host_is_superhost                  object
# host_has_profile_pic               object
# host_identity_verified             object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# accommodates                        int64
# bedrooms                          float64
# bathrooms                         float64
# beds                              float64
# price                             float64
# minimum_nights                      int64
# maximum_nights                      int64
# ...

# %% [markdown]
# Como se muestra arriba, podemos ver que el tipo de datos de `host_response_time` y `host_response_rate` es object, `bathrooms` es float64 y `price` es también es float64, etc. Los datos que tengan una asignación incorrecta de tipos pueden causar problemas en el análisis, como cálculos erróneos o la imposibilidad de realizar ciertas operaciones. Por lo tanto, es importante asegurarse de que los tipos de datos estén correctamente asignados para garantizar la precisión y la eficacia de cualquier análisis posterior.

# %% [markdown]
# ### **Data Info**

# %% [markdown]
# Otro método que podemos utilizar para obtener información sobre nuestro conjunto de datos es el método `DataFrame.info()`.
#
# La función `info()` proporciona un resumen conciso del DataFrame, incluyendo detalles como el número de filas y columnas, el nombre de cada columna, el tipo de datos de cada columna, la cantidad de valores no nulos y el uso de memomria, la cantidad de memoria que está siendo utilizada por el DataFrame en el sistema.
#
# Este método es útil para tener una visión general de la estructura de nuestros datos y para identificar rápidamente posibles problemas, como valores nulos o tipos de datos incorrectos. Además, la información que devuelve `info()` es presentada de manera clara y organizada, lo que facilita la comprensión y el análisis de nuestro conjunto de datos.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16249 entries, 0 to 16248
# Data columns (total 34 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              16249 non-null  float64
#  1   listing_url                     16249 non-null  object
#  2   host_id                         16249 non-null  int64
#  3   host_name                       16248 non-null  object
#  4   host_since                      16248 non-null  object
#  5   host_response_time              15812 non-null  object
#  6   host_response_rate              15812 non-null  object
#  7   host_acceptance_rate            15881 non-null  object
#  8   host_is_superhost               16082 non-null  object
#  9   host_has_profile_pic            16248 non-null  object
#  10  host_identity_verified          16248 non-null  object
#  11  neighbourhood                   16249 non-null  object
# ...

# %% [markdown]
# ## **6. Data Wrangling**

# %% [markdown]
# En esta sección, llevamos a cabo el proceso de Data Wrangling, también conocido como prepración de datos o limpieza de datos.
#
# Data Wrangling es el proceso de transformar datos brutos o sin procesar (raw data) en otro formato con la intención de prepararlos y hacerlos más apropiados, confiables y valiosos para una variedad de propósitos, como análisis, visualización o modelado. Como consecuencia de este proceso, los datos que se analizan son más precisos y significativos, y generan mejores conocimientos y resultados.
#
# Este proceso incluye una serie de pasos para asegurar la calidad y consistencia de los datos antes de realizar el análisis. Las tareas que comunmente se realizan en este proceso son:
#
# * Manejo de datos faltantes (Handling Missing Data)
# * Formateo o estandarización de datos (Data Formatting).
# * Normalización de datos (Data Normalization).
# * Agrupamiento de datos (Data Binning).
# * Conversión de variables categóricas en variables numéricas (Dummy Variables)
#
# El objetivo principal de estas tareas es garantizar que los datos estén en un formato adecuado y listos para su posterior análisis.

# %% [markdown]
# ### **Missing Data**

# %% [markdown]
# Uno de los aspectos críticos en cualquier análisis de datos es la gestión de los valores faltantes. Los datos faltantes pueden surgir por diversas razones, como errores en la recopilación de datos o simplemente porque cierta información no está disponible. Por lo general, el valor faltante en el conjunto de datos aparece como un signo de interrogación '?', 'N/A, '0', o simplemente como una celda en blanco.
#
# Primero, es importante comprender la distribución de los datos faltantes en nuestro conjunto de datos, ya que estos pueden afectar la integridad y calidad de nuestro análisis. Los datos faltantes pueden introducir sesgos, impactar la precisión de las estadísticas y gráficos, y conducir a conclusiones erróneas si no se manejan correctamente. Entender esta distribución nos permite tomar decisiones informadas sobre cómo abordar los datos faltantes.
#
# Después de conocer la distribución de nuestros datos faltantes, lo siguiente es tratar de manera adecuada estos datos, esto es crucial para garantizar la precisión, la confiabilidad y las conclusiones que extraemos de nuestro análisis. Nos permite obtener resultados más confiables, mejorar la integridad de los datos y maximizar la utilización de la información disponible, lo que a su vez contribuye a la toma de decisiones informadas y efectivas.
#
# En esta sección, nos enfocamos en abordar este desafío de manera sistemática y efectiva.

# %% [markdown]
# #### **Identifying missing data**

# %% [markdown]
# Primero, realizamos un análisis para identificar las variables que contienen valores faltantes. Esta etapa es importante para comprender la magnitud del problema y su impacto en nuestro análisis. Después, evaluamos diferentes estrategias para manejar los datos ausentes, que pueden incluir desde la eliminación de filas o columnas con valores faltantes hasta técnicas de imputación que nos permiten estimar valores basados en información disponible.

# %% [markdown]
# Para identificar los valores faltantes en cada variable, creamos un DataFrame con valores booleanos que indiquen la presencia de valores faltantes en cada celda de nuestro conjunto de datos.

# %%
missing_data = df.isna()
display(missing_data)
# Out:
#           id  listing_url  host_id  host_name  host_since  host_response_time  \
# 0      False        False    False      False       False               False
# 1      False        False    False      False       False               False
# 2      False        False    False      False       False               False
# 3      False        False    False      False       False               False
# 4      False        False    False      False       False               False
# ...      ...          ...      ...        ...         ...                 ...
# 16244  False        False    False      False       False               False
# 16245  False        False    False      False       False               False
# 16246  False        False    False      False       False               False
# 16247  False        False    False      False       False               False
# 16248  False        False    False      False       False               False
#
# ...

# %% [markdown]
# Los valores boolenaos indican la presencia (True) o ausencia (False) de valores faltantes en cada celda de nuestro conjunto de datos.
#
# Excluimos las variables que no tienen ningún valor True en el DataFrame `missing_data`, es decir, nuestro DataFrame `missing_data` contendrá solo las columnas que tienen al menos un valor faltante.

# %%
missing_data = missing_data.loc[:, missing_data.any(axis= 0)]
display(missing_data)
# Out:
#        host_name  host_since  host_response_time  host_response_rate  \
# 0          False       False               False               False
# 1          False       False               False               False
# 2          False       False               False               False
# 3          False       False               False               False
# 4          False       False               False               False
# ...          ...         ...                 ...                 ...
# 16244      False       False               False               False
# 16245      False       False               False               False
# 16246      False       False               False               False
# 16247      False       False               False               False
# 16248      False       False               False               False
#
#        host_acceptance_rate  host_is_superhost  host_has_profile_pic  \
# ...

# %% [markdown]
# #### **Counting missing data**

# %% [markdown]
# Usando un bucle `for` en Python, podemos calcular rápidamente la cantidad de valores faltantes en cada variable de `missing_data` y el porcentaje que representan.

# %%
for column in missing_data.columns:
    print(" ")
    print(f"Variable: {column}")
    print(f"Missing Values: {missing_data[column].sum()} de {len(missing_data)}")
    print(f"% NaNs: {(missing_data[column].sum()/len(missing_data)*100).round(2)}")
# Out:
#
# Variable: host_name
# Missing Values: 1 de 16249
# % NaNs: 0.01
#
# Variable: host_since
# Missing Values: 1 de 16249
# % NaNs: 0.01
#
# Variable: host_response_time
# Missing Values: 437 de 16249
# % NaNs: 2.69
#
# Variable: host_response_rate
# Missing Values: 437 de 16249
# % NaNs: 2.69
#
# Variable: host_acceptance_rate
# Missing Values: 368 de 16249
# % NaNs: 2.26
#
# Variable: host_is_superhost
# Missing Values: 167 de 16249
# % NaNs: 1.03
#
# Variable: host_has_profile_pic
# Missing Values: 1 de 16249
# % NaNs: 0.01
#
# Variable: host_identity_verified
# Missing Values: 1 de 16249
# % NaNs: 0.01
#
# Variable: bedrooms
# Missing Values: 305 de 16249
# % NaNs: 1.88
#
# Variable: bathrooms
# Missing Values: 3 de 16249
# % NaNs: 0.02
#
# Variable: beds
# Missing Values: 179 de 16249
# % NaNs: 1.1
#
# Variable: price
# Missing Values: 149 de 16249
# % NaNs: 0.92
#
# Variable: review_scores_accuracy
# Missing Values: 1 de 16249
# % NaNs: 0.01
#
# ...

# %% [markdown]
# #### **Handling missing data**

# %% [markdown]
# Ahora que hemos identificado las variables con valores faltantes y la distribución de estos en cada una, procederemos a realizar un manejo adecuado de los datos faltantes utilizando diversas técnicas y herramientas. Podemos lidiar con los datos faltantes de la siguientes maneras:
#
# 1. Eliminar datos
#     * Eliminar toda la fila
#     * Eliminar toda la columna<br>
#     <br>
# 2. Reemplazar datos
#     * Reemplazarlos por media o mediana
#     * Reemplazarlos por frecuencia
#     * Reemplazarlos según otras funciones

# %% [markdown]
# ##### **Delete Entire Column**
#
# Las columnas enteras deben eliminarse sólo si la mayoría de los datos de la variable son faltantes o si la columna con valores NaN no es relevante o no aporta información significativa para el análisis. En nuestro conjunto de datos, ninguna de las columnas está lo suficientemente vacía como para eliminarla por completo y las columnas que no era relevantes para este análisis fueron eliminadas en el proceso previo de limpieza descrito al incio de este proyecto.

# %% [markdown]
# ##### **Delete Entire Row**

# %% [markdown]
# La variable `price`, que indica el precio por noche del alojamiento, juega un papel fundamental en nuestro proyecto, ya que representa la variable de mayor interés en nuestro conjunto de datos de alojamientos de Airbnb en la Ciudad de México. Su análisis nos permite entender las dinámicas de precios, identificar tendencias y determinar los factores clave que influyen en las tarifas de alquiler.
#
# Es importante destacar que, a pesar de la importancia de esta variable, el porcentaje de valores NaN en `price` es muy pequeño, representando solo un 0.92% de los registros.

# %% [markdown]
# Dado que estos valores afectan a un porcentaje muy pequeño de nuestro conjunto de datos y para mantener la integridad y coherencia de nuestro análisis, hemos decidido eliminar estos registros específicos. Al eliminar estos registros, se asegura la coherencia y la integridad de los datos restantes, evitando posibles sesgos o interpretaciones erróneas que podrían surgir al imputar valores o mantener registros incompletos.

# %%
# Eiminar registros con valores NaN en 'price'

df = df.dropna(subset= ['price'])

# %% [markdown]
# Restablecemos el índice debido a que eliminamos filas. El parámetro `drop=True` asegura que la columna antigua de índices se descarte y no se conserve como una columna en el DataFrame resultante.

# %%
df = df.reset_index(drop=True)

# %% [markdown]
# ##### **Handle numeric variables**

# %% [markdown]
# A continuación se abordará el tratamiento de valores faltantes en las variables numéricas de nuestro conjunto de datos. Se analizarán diferentes formas o técnicas para tratar los valores faltantes, como la imputación con la media o la mediana, la imputación basada en información adicional, entre otras, con el objetivo de garantizar que la ausencia de datos se refleje de manera clara y precisa en el análisis final.

# %% [markdown]
# Primero, separamos nuestras variables numéricas y categóricas que contienen valores NaN para tratarlos por separado.

# %%
# crear DataFrame de variables númericas con valores NaN

missing_data_numeric = df.select_dtypes(include = 'number').isna()
missing_data_numeric = missing_data_numeric.loc[:, missing_data_numeric.any(axis = 0)]
missing_data_numeric
# Out:
#        bedrooms  bathrooms   beds  review_scores_accuracy  \
# 0         False      False  False                   False
# 1         False      False  False                   False
# 2         False      False  False                   False
# 3         False      False  False                   False
# 4         False      False  False                   False
# ...         ...        ...    ...                     ...
# 16095     False      False  False                   False
# 16096     False      False  False                   False
# 16097     False      False  False                   False
# 16098     False      False   True                   False
# 16099     False      False  False                   False
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                          False                  False
# 1                          False                  False
# 2                          False                  False
# ...

# %% [markdown]
# Calculamos la cantidad de valores faltantes en cada variable numérica de `missing_data_numeric` y el porcentaje que representan.

# %%
for column in missing_data_numeric.columns:
    print(" ")
    print(f"Variable: {column}")
    print(f"Missing Values: {missing_data_numeric[column].sum()} de {len(missing_data_numeric)}")
    print(f"% NaNs: {(missing_data_numeric[column].sum()/len(missing_data_numeric)*100).round(2)}")
# Out:
#
# Variable: bedrooms
# Missing Values: 304 de 16100
# % NaNs: 1.89
#
# Variable: bathrooms
# Missing Values: 3 de 16100
# % NaNs: 0.02
#
# Variable: beds
# Missing Values: 176 de 16100
# % NaNs: 1.09
#
# Variable: review_scores_accuracy
# Missing Values: 1 de 16100
# % NaNs: 0.01
#
# Variable: review_scores_cleanliness
# Missing Values: 1 de 16100
# % NaNs: 0.01
#
# Variable: review_scores_checkin
# Missing Values: 1 de 16100
# % NaNs: 0.01
#
# Variable: review_scores_communication
# Missing Values: 1 de 16100
# % NaNs: 0.01
#
# Variable: review_scores_location
# Missing Values: 1 de 16100
# % NaNs: 0.01
#
# Variable: review_scores_value
# Missing Values: 3 de 16100
# % NaNs: 0.02

# %% [markdown]
# Para las variables `bedrooms`, `bathrooms` y `beds` optamos por imputar los valores faltantes utilizando la mediana. Esta elección se basa en que la mediana ofrece una solución robusta al ser menos sensible a valores extremos (que son comunes en conjuntos de datos de este tipo). Cuando hablamos de la cantidad de habitaciones (bedrooms), baños (bathrooms) o camas (beds) en alojamientos, es común que estos valores se distribuyan de manera no uniforme, es decir, que haya más alojamientos con cierta cantidad de habitaciones o baños que con otras cantidades. En este sentido, la mediana, al ser una medida que se encuentra en el punto medio de un conjunto de datos ordenados, refleja mejor cuál es la cantidad más típica de habitaciones, baños o camas que se encuentra en nuestra muestra de alojamientos. También de esta manera se evita la introducción de fracciones en variables que naturalmente se expresan en números enteros
#
# Por lo tanto, al utilizar la mediana para imputar los valores faltantes en  `bedrooms`, `bathrooms` y `beds`, aseguramos una aproximación más robusta y representativa de la distribución típica de estas características en nuestra muestra de alojamientos.

# %%
# Mediana de 'bedrooms', 'bathroom's y 'beds'

df[['bedrooms','bathrooms','beds']].median()
# Out:
# bedrooms     1.0
# bathrooms    1.0
# beds         2.0
# dtype: float64

# %%
# Imputar valores NaN en 'bedrooms' 

df['bedrooms'] = df['bedrooms'].fillna(df['bedrooms'].median())

# %%
# Imputar valores NaN en 'bathrooms' 

df['bathrooms'] = df['bathrooms'].fillna(df['bathrooms'].median())

# %%
# Imputar valores NaN en 'beds' 

df['beds'] = df['beds'].fillna(df['beds'].median())

# %% [markdown]
# En las variables `review_scores_accuracy`, `review_scores_cleanliness`, `review_scores_checkin`, `review_scores_communication`, `review_scores_location` y `review_scores_value`, que corresponden a las puntuaciones de reseña de los alojamientos, también se imputarán los valores faltantes utilizando la mediana.

# %%
df.loc[:,'review_scores_accuracy':'review_scores_value'].median()
# Out:
# review_scores_accuracy         4.88
# review_scores_cleanliness      4.86
# review_scores_checkin          4.92
# review_scores_communication    4.92
# review_scores_location         4.92
# review_scores_value            4.81
# dtype: float64

# %% [markdown]
# Creamos un diccionario que contiene los valores de la medias que imputaremos en cada variable correspondiente.

# %%
imputed_values_reviews = {
    'review_scores_accuracy': 4.88,
    'review_scores_cleanliness': 4.86,
    'review_scores_checkin': 4.92,
    'review_scores_communication': 4.92,
    'review_scores_location': 4.92,
    'review_scores_value': 4.81
}

# %% [markdown]
# Luego, utilizamos el método `fillna()` con este diccionario como argumento para reemplazar los valores NaN con los valores especificados en `imputed_values_reviews`

# %%
df.fillna(imputed_values_reviews, inplace= True)

# %% [markdown]
# Verificamos que el tratamiento de valores faltantes en nuestras variables numéricas se haya realizado de forma correcta.

# %%
# Cantidad de valores NaN en las variables numericas despues del proceso de tratamiento

df.select_dtypes(include= 'number').isna().sum()
# Out:
# id                                0
# host_id                           0
# latitude                          0
# longitude                         0
# accommodates                      0
# bedrooms                          0
# bathrooms                         0
# beds                              0
# price                             0
# minimum_nights                    0
# maximum_nights                    0
# number_of_reviews                 0
# review_scores_rating              0
# review_scores_accuracy            0
# review_scores_cleanliness         0
# review_scores_checkin             0
# review_scores_communication       0
# review_scores_location            0
# review_scores_value               0
# calculated_host_listings_count    0
# reviews_per_month                 0
# dtype: int64

# %% [markdown]
# Hemos completado el proceso de tratamiento de valores faltantes en nuestras variables numéricas, asegurando que nuestros datos estén completos y listos las siguientes etapas de limpieza y posterior analisis. Ahora, procederemos con el tratamiento de los valores faltantes de las variables categóricas.

# %% [markdown]
# ##### **Handle categorical variables**

# %% [markdown]
# Para tratar los valores faltantes en nuestras variables categóricas podemos considerar opciones como reemplazarlos con el valor que aparece con mayor frecuencia o la creación de categorías especiales para representar los valores NaN, entre otras.

# %%
# crear DataFrame de variables categóricas con valores NaN

missing_data_categoric = df.select_dtypes(include = 'object').isna()
missing_data_categoric = missing_data_categoric.loc[:, missing_data_categoric.any(axis = 0)]
missing_data_categoric
# Out:
#        host_name  host_since  host_response_time  host_response_rate  \
# 0          False       False               False               False
# 1          False       False               False               False
# 2          False       False               False               False
# 3          False       False               False               False
# 4          False       False               False               False
# ...          ...         ...                 ...                 ...
# 16095      False       False               False               False
# 16096      False       False               False               False
# 16097      False       False               False               False
# 16098      False       False               False               False
# 16099      False       False               False               False
#
#        host_acceptance_rate  host_is_superhost  host_has_profile_pic  \
# ...

# %% [markdown]
# Calculamos la cantidad de valores faltantes en cada variable categorica que contiene al menos un valor NaN y el porcentaje que representan.

# %%
for column in missing_data_categoric.columns:
    print(" ")
    print(f"Variable: {column}")
    print(f"Missing Values: {missing_data_categoric[column].sum()} de {len(missing_data_categoric)}")
    print(f"% NaNs: {(missing_data_categoric[column].sum()/len(missing_data_categoric)*100).round(2)}")
# Out:
#
# Variable: host_name
# Missing Values: 1 de 16100
# % NaNs: 0.01
#
# Variable: host_since
# Missing Values: 1 de 16100
# % NaNs: 0.01
#
# Variable: host_response_time
# Missing Values: 429 de 16100
# % NaNs: 2.66
#
# Variable: host_response_rate
# Missing Values: 429 de 16100
# % NaNs: 2.66
#
# Variable: host_acceptance_rate
# Missing Values: 363 de 16100
# % NaNs: 2.25
#
# Variable: host_is_superhost
# Missing Values: 165 de 16100
# % NaNs: 1.02
#
# Variable: host_has_profile_pic
# Missing Values: 1 de 16100
# % NaNs: 0.01
#
# Variable: host_identity_verified
# Missing Values: 1 de 16100
# % NaNs: 0.01

# %% [markdown]
# Podemos observar la presencia de valores NaN en varias variables categóricas. Tras evaluar la proporción de los valores faltantes en las variables `host_response_time`, `host_has_profile_pic`, `host_is_superhost` y `host_identity_verified`, hemos decidido imputarlos utilizando la moda en lugar de crear categorías especiales. Esta decisión se basa en el hecho de que los valores faltantes no representan una proporción significativa de los datos, y la imputación por la moda nos proporcionará estimaciones mas precisas basadas en los valores más frecuentes observados en nuestro conjunto de datos. La presencia de una categoría especial podría introducir ambigüedad en la interpretación de los datos y dificultar la comparación entre los grupos de las variables.

# %%
# Imputar valores NaN en 'host_response_time'

df['host_response_time'] = df['host_response_time'].replace(np.NaN, df['host_response_time'].mode()[0])

# %%
# Imputar valores NaN en 'host_has_profile_pic'

df['host_has_profile_pic'] = df['host_has_profile_pic'].replace(np.NaN, df['host_has_profile_pic'].mode()[0])

# %%
# Imputar valores NaN en 'host_is_superhost'

df['host_is_superhost'] = df['host_is_superhost'].replace(np.NaN, df['host_is_superhost'].mode()[0])

# %%
# Imputar valores NaN en 'host_identity_verified'

df['host_identity_verified'] = df['host_identity_verified'].replace(np.NaN, df['host_identity_verified'].mode()[0])

# %% [markdown]
# Para las variables `host_response_rate` y `host_acceptance_rate`, reemplazaremos los valores faltantes utilizando la media de los valores existentes en esas columnas. Esta decisión se basa en la necesidad de mantener la estructura numérica de los datos (porcentajes) y evitar la pérdida de información significativa al eliminar filas con NaN.
#
# Las variables `host_response_rate` y `host_acceptance_rate` contienen porcentajes y está representadas como tipo object en Pandas, puede ser conveniente convertirlas al tipo de datos numérico apropiado para porcentajes, que es el tipo float, antes de imputar los valores faltantes.

# %%
# Convertir variable 'host_response_rate' a float

df['host_response_rate'] = df['host_response_rate'].str.rstrip('%').astype('float').div(100).round(2)

# %%
# Convertir variable 'host_acceptance_rate' a float

df['host_acceptance_rate'] = df['host_acceptance_rate'].str.rstrip('%').astype('float').div(100).round(2)

# %%
# Reemplazar valores NaN en 'host_response_rate' con la media

df['host_response_rate'] = \
    df['host_response_rate'].replace(np.NaN, df['host_response_rate'].mean().round(2))

# %%
# Reemplazar valores NaN en 'host_acceptance_rate' con la media

df['host_acceptance_rate'] = \
    df['host_acceptance_rate'].replace(np.NaN, df['host_acceptance_rate'].mean().round(2))

# %% [markdown]
# Para la variable `host_name` se creará una categoría especial denominada 'unknown' para representar los valores NaN, esto ayudará a identificar que esos registros no tienen un nombre de anfitrion registrado o que por algún motivo no está disponible esa información.

# %%
# Reemplazar valores NaN en 'host_name' con la categoria 'unknown'

df['host_name'] = df['host_name'].replace(np.NaN, "unknown")

# %% [markdown]
# Para la variable `host_since`, que representa la fecha en la que el anfintrión se registró o creó su usuario en la plataforma, se reemplazarán los valores faltantes por la media.

# %%
# Convertir variable 'host_since' a datetime

df['host_since'] = pd.to_datetime(df['host_since'], format='%d/%m/%Y')

# %%
# Reemplazar valores NaN en 'host_since' con la media

df['host_since'] = df['host_since'].replace(np.NaN, df['host_since'].mean())

# %% [markdown]
# ¡Listo! Ahora tenemos un conjunto de datos sin valores faltantes.
#
# Hemos finalizado el tratamiento de datos faltantes en nuestro conjunto de datos, asegurando la eliminación de todos los valores NaN y preparándonos para avanzar con el proceso de limpieza y el análisis detallado de los datos. Ahora procederemos con la etapa de formateo de datos para asegurar que todas las variables estén en el formato adecuado y sean consistentes en su estructura.

# %%
# Cantidad de valores NaN en las variables categoricas despues del proceso de tratamiento

df.isna().sum()
# Out:
# id                                0
# listing_url                       0
# host_id                           0
# host_name                         0
# host_since                        0
# host_response_time                0
# host_response_rate                0
# host_acceptance_rate              0
# host_is_superhost                 0
# host_has_profile_pic              0
# host_identity_verified            0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# accommodates                      0
# bedrooms                          0
# bathrooms                         0
# beds                              0
# price                             0
# minimum_nights                    0
# maximum_nights                    0
# first_review                      0
# last_review                       0
# number_of_reviews                 0
# review_scores_rating              0
# ...

# %% [markdown]
# ### **Data Formatting**

# %% [markdown]
# Los datos generalmente se recopilan de diferentes lugares, por diferentes personas, y pueden almacenarse en diferentes formatos. El formateo de datos se refiere al proceso de darle formato a los datos de manera que sigan un estándar o una estructura específica que nos permita a los analistas realizar interpretaciones, comparaciones y analisis significativos.
#
# Esto puede implicar la estandarización de unidades, conversión de tipos datos, notaciones o cualquier otro aspecto que sea relevante para la representación coherente de la información en el mismo formato, unidad o convención.
#
# Como parte de la limpieza del conjunto de datos, el formateo de datos garantizará que los datos sean coherentes y entendibles, facilitando su uso para analisis posteriores.

# %% [markdown]
# #### **Correct data format**

# %% [markdown]
# Este paso en la limpieza de datos consiste en verificar y asegurarse de que todos los datos estén en el formato correcto (int, float, text u otro). Asegurarse de que cada variable tenga el tipo de datos correcto para su naturaleza. Por ejemplo, las fechas deberían estar representadas como objetos de fecha en lugar de cadenas de texto, y las variables numéricas deberían ser de tipo numérico en lugar de objetos.
#
# En Pandas, usamos:
#
# * `dtype()` para comprobar el tipo de datos
#
# * `astype()` para cambiar el tipo de datos

# %%
# Comprobar tipos de datos

df.dtypes
# Out:
# id                                       float64
# listing_url                               object
# host_id                                    int64
# host_name                                 object
# host_since                        datetime64[ns]
# host_response_time                        object
# host_response_rate                       float64
# host_acceptance_rate                     float64
# host_is_superhost                         object
# host_has_profile_pic                      object
# host_identity_verified                    object
# neighbourhood                             object
# latitude                                 float64
# longitude                                float64
# room_type                                 object
# accommodates                               int64
# bedrooms                                 float64
# bathrooms                                float64
# beds                                     float64
# ...

# %% [markdown]
# Como podemos ver arriba, algunas columnas no tienen el tipo de datos correcto. Las variables numéricas deben tener el tipo floa o int, y las variables con cadenas como categorías deben tener el tipo object.
#
# Las variables `bedrooms` y `beds` solo contienen valores enteros y no contienen fracciones, lo más adecuado sería cambiar el tipo de datos de float a int para reflejar correctamente el tipo de datos de estas variables.
#
# Las variables `host_since`, `first_review` y `last_review` contienen fechas y, por lo tanto, deben ser convertidas al tipo de datos datetime, que es el adecuado para manejar fechas en Pandas.
#
# Realizaremos las conversiones de los tipos de datos al formato adecuado para cada variable utilizando el método `astype()`.

# %% [markdown]
# - Variable `bedrooms`

# %%
# Convertir variable 'bedrooms' a int

df[['bedrooms']] = df[['bedrooms']].astype('int')

# %% [markdown]
# - Variable `beds`

# %%
# Convertir variable 'beds' a int

df[['beds']] = df[['beds']].astype('int')

# %% [markdown]
# - Variable `first_review`

# %%
# Convertir variable 'firts_review' a datetime

df['first_review'] = pd.to_datetime(df['first_review'], format='%d/%m/%Y')

# %% [markdown]
# - Variable `last_review`

# %%
# Convertir variable 'last_review' a datetime

df['last_review'] = pd.to_datetime(df['last_review'], format='%d/%m/%Y')

# %% [markdown]
# Tras aplicar el método `astype()` para convertir nuestras variables al tipo de datos apropiado, verificamos la correcta ejecución de estas conversiones. Esto implica revisar los tipos de datos de cada variable para asegurarnos de que sean objetos, enteros, flotantes según lo previsto. Además, también es fundamental comprobar que no se haya perdido información relevante durante esta conversión, garantizando así la integridad y la coherencia de nuestros datos para un análisis preciso y confiable.

# %%
# Verificar tipos de datos despues de la conversión

df.dtypes
# Out:
# id                                       float64
# listing_url                               object
# host_id                                    int64
# host_name                                 object
# host_since                        datetime64[ns]
# host_response_time                        object
# host_response_rate                       float64
# host_acceptance_rate                     float64
# host_is_superhost                         object
# host_has_profile_pic                      object
# host_identity_verified                    object
# neighbourhood                             object
# latitude                                 float64
# longitude                                float64
# room_type                                 object
# accommodates                               int64
# bedrooms                                   int32
# bathrooms                                float64
# beds                                       int32
# ...

# %%
# Guardar df como CSV

df.to_csv('../data/listings_cleaned.csv', index = False)

# %% [markdown]
# ## **7. Exploratory Data Analysis (EDA)**

# %% [markdown]
# El Análisis Exploratorio de Datos (EDA) es una fase crucial que se realiza para explorar y comprender las principales características, patrones y tendencias presentes en un conjunto de datos. El EDA implica un proceso iterativo de cuestionar, analizar y visualizar nuestros datos.
#
# Sus objetivos principales son:
#
# * Resumir las características principales de los datos.
# * Comprender mejor el conjunto de datos.
# * Identificar patrones y tendencias.
# * Descubrir relaciones significativas entre diferentes variables.
# * Detectar valores atípicos o anomalías en los datos.
# * Probar o generar hipotesis y suposiciones.
# * Identificar y extraer las variables importantes para el problema o cuestión.
# * Comprender y extraer insights valiosos de los datos.

# %% [markdown]
# En esta etapa del proyecto, nos enfocaremos en analizar a detalle el mercado de alojamientos de Airbnb en la Ciudad de México para obtener una comprensión profunda de los datos y extraer valiosos insights.
#
# Utilizaremos distintas técnicas estadísticas y de visualización para identificar patrones, tendencias y relaciones significativas entre variables. Exploraremos la distribución geográfica de los alojamientos y analizaremos la variación de precios por zonas para entender mejor las dinámicas del mercado. También trataremos de identificar los factores clave que mas influyen en los precios de renta de los alojamientos.  Nuestro objetivo durante esta etapa será tratar de resolver las preguntas clave planteadas al inicio del proyecto y obtener insights que puedan respaldar decisiones estratégicas en el mercado de alojamientos de Airbnb en la Ciudad de México.

# %% [markdown]
# ### **Univariate Analysis of Price**

# %% [markdown]
# El propósito del análisis univariado es explorar y comprender las características individuales de una variable en un conjunto de datos. Realizar un análisis univariado de la variable `price` nos proporcionará una comprensión inicial y esencial de la distribución y características estadísticas básicas de nuestra variable de interés.
#
# Aquí hay algunas razones por las que realizar un análisis univariado de `price` podría ser beneficioso para nuestro objetivo:
#
# * Distribución de precios: Un análisis univariado nos permitirá examinar la distribución de los precios. Identificar tendencias centrales, como la media y la mediana, y comprender la dispersión de los precios de renta de los alojamientos de Airbnb en la Ciudad de México.
#
# * Valores atípicos: Al estudiar la distribución, podríamos identificar la presencia de valores atípicos (outliers) en los precios. Los valores atípicos pueden influir significativamente en el análisis y, por lo tanto, es crucial entender si existen y cómo afectan la distribución de los precios.
#
# * Medidas de tendencia central: Calcular medidas como la media y la mediana nos proporcionará información sobre el precio típico de los alojamientos en nuestro conjunto de datos. Esto nos ayudará a obtener una visión general de la ubicación central de los precios.
#
# * Dispersión de datos: Al analizar la dispersión, como la desviación estándar o el rango intercuartílico, podremos entender cuán dispersos están los precios. Esto es importante para evaluar la variabilidad y la consistencia en los precios de los alojamientos.
#
# * Visualización gráfica: La representación gráfica mediante histogramas, boxplots u otros gráficos relevantes nos permitirá visualizar la distribución de los precios de los alojamientos. Esto nos proporcionará información visual sobre la forma de la distribución y posiblemente revelar patrones o comportamientos inesperados.

# %% [markdown]
# #### **Price Distribution**

# %% [markdown]
# Para entender la distribución y la variabilidad de los precios de alojamientos utilizaremos la función `describe()`. Esta función nos permitirá obtener un resumen estadístico de la variable `price` incluyendo medidas como el promedio, la mediana y la desviación estándar. La variable `price` representa el precio de renta por noche de los alojamientos.

# %%
df['price'].describe().round(2)
# Out:
# count    16100.00
# mean      1401.98
# std       1669.37
# min         78.00
# 25%        639.75
# 50%       1000.00
# 75%       1597.00
# max      47719.00
# Name: price, dtype: float64

# %% [markdown]
# De este resumen podemos destacar la siguientes observaciones:
#
# * **count:**
#     Este valor indica que hay 16,100 observaciones (listados) en el conjunto de datos para la variable `price`.
#
# * **mean (media):**
#     La media de `price` es aproximadamente 1,401.98. Esto sugiere que, en promedio, el precio por noche de los alojamientos en la Ciudad de México es alrededor de $1,401.98 pesos mexicanos
#
# * **std (desviación estándar):**
#     La desviación estándar es aproximadamente 1,669.37. Esta medida indica la dispersión de los valores alrededor de la media. La desviación estándar de aproximadamente $1,669.37 indica que, en promedio, los precios de los alojamientos tienden a desviarse alrededor de este valor de la media. Es decir, se esperaría que la mayoría de los valores de `price` estén dentro de un rango cercano a la media, determinado por la desviación estándar, dentro del rango de la media +- una desviación estándar ($1,401.92 +- $1,669.41 ).
#     Una desviación estándar alta sugiere una mayor variabilidad en los precios, en nuestro caso la desviación estándar es relativamente grande, lo que sugiere que hay una amplia gama de precios, con algunos precios muy por encima de la media y otros muy por debajo. Dado que la desviación estándar es alta y sugiere una mayor variabilidad en los precios, es posible que la distribución de los datos sea más bien sesgada.
#
# * **min (mínimo):**
#     El valor mínimo de `price` es $78.00. Este es el precio más bajo observado en el conjunto de datos.
#
# * **25% (primer cuartil):**
#     El 25% de los precios están por debajo de $639.75. Esto nos proporciona información sobre la distribución de los precios en el rango más bajo.
#
# * **50% (mediana):**
#     La mediana de `price` es $1,000.00. Este valor indica que el 50% de los alojamientos están por debajo de un precio por noche de $1,000.00 pesos mexicanos. Esta información nos es útil para entender la ubicación central de los precios.
#
# * **75% (tercer cuartil):**
#     El 75% de los precios están por debajo de $1597.00. Similar al primer cuartil, esto da información sobre la distribución de precios en el rango más alto.
#
# * **max (máximo):**
#     El valor máximo de `price` es $47,719.00. Este es el precio más alto observado en el conjunto de datos.

# %% [markdown]
# #### **Skewness and Kurtosis**

# %% [markdown]
# La asimetría (skewness) y la curtosis (kurtosis) son medidas estadísticas que proporcionan información sobre la forma y las características de una distribución de datos. Proporcionan medidas cuantitativas que ayudan a comprender la forma, simetría y características específicas de una distribución. Y son útiles para identificar la presencia de sesgo, colas pesadas, o características que difieren de una distribución normal.
#
# La skewness mide la asimetría o la falta de simetría en una distribución de datos.
#
# Interpretación:
# * Skewness positiva: La cola derecha de la distribución es más larga o pesada que la cola izquierda. La mayoría de los datos se concentran en el lado izquierdo.
# * Skewness negativa: La cola izquierda de la distribución es más larga o pesada que la cola derecha. La mayoría de los datos se concentran en el lado derecho.
# * Skewness cercana a cero: La distribución es aproximadamente simétrica.
#
# Una cola larga puede referirse tanto a una mayor probabilidad de observar valores extremos como a la extensión física de la cola en sí. Una cola larga indica que la cola se extiende más lejos de la media en comparación con una distribución normal.
#
# La kurtosis mide la "tailedness" o "pesadez de la cola" de una distribución de datos e indica el grado de concentración de la distribución alrededor de su media. La pesadez de la cola se refiere a una mayor o menor probabilidad de observar valores extremos en las colas de la distribución en comparación con lo que se esperaría en una distribución normal. En una cola pesada, la concentración de datos en la región central es alta, pero hay una probabilidad relativamente alta de observar valores extremos lejos de la media.
#
# Interpretación:
# * Kurtosis positiva: Colas más pesadas y una distribución más puntiaguda (leptocúrtica) que la distribución normal.
# * Kurtosis negativa: Colas más ligeras y una distribución más achatada (platicúrtica) que la distribución normal.
# * Kurtosis igual a cero: La distribución tiene la misma pesadez de cola que la distribución normal (mesocúrtica).
#
# Mientras que la curtosis se centra en las colas y la concentración de datos, la skewness se enfoca en la simetría o asimetría direccional de la distribución.
#
# En nuestro análisis univariante de la variable 'price', calcular las medidas de asimetría y curtosis antes de visualizar la distribución puede proporcionar un contexto inicial sobre la forma general de la distribución.

# %% [markdown]
# Para calcular la asimetría y la curtosis utilizamos las funciones estadísticas en Python `stats.skew()` y `stats.kurtosis()`

# %%
# Calcular la asimetría y la curtosis

skew_price = stats.skew(df['price']).round(2)
kurtosis_price = stats.kurtosis(df['price']).round(2)

print(f"Skewness= {skew_price}, Kurtosis= {kurtosis_price}")
# Out:
# Skewness= 8.4, Kurtosis= 137.07

# %% [markdown]
# Interpretamos las medidas proporcionadas por las funciones estadísticas:
#
# * **Asimetría (skewness): 8.4**
# Un valor de asimetría positivo indica sesgo a la derecha. En este caso, la cola derecha de la distribución es más larga o pesada que la cola izquierda. En términos prácticos, esto sugiere que hay valores más altos o extremos en el lado derecho de la distribución, lo que podría indicar la presencia de algunos alojamientos con precios significativamente más altos. La asimetría positiva sugiere que la distribución de los precios está sesgada a la derecha, con la presencia de algunos valores extremadamente altos.
#
# * **Curtosis (kurtosis): 137.07**
# Un valor de curtosis positivo indica que la distribución tiene colas más pesadas y es más puntiaguda que una distribución normal (leptocúrtica), lo que podría indicar la presencia de valores extremos y una mayor concentración de datos alrededor de la media. Esto significa que hay una mayor concentración de datos en la región central de la distribución y una mayor probabilidad de observar valores extremos en las colas, especialmente en el lado derecho debido a la asimetría positiva.

# %% [markdown]
# Estas interpretaciones nos proporcionan una visión general de la forma de la distribución de la variable `price`, proporcionando información sobre la concentración de datos alrededor de la media, la presencia de valores extremos y la simetría de la distribución. Sin embargo, también es útil visualizar la distribución utilizando herramientas gráficas, como el histograma o el gráfico de densidad, para obtener una comprensión más completa de la forma de la distribución.
#
# A continuación, procederemos a representar visualmente la distribución de los datos de la variable `price` mediante estas herramientas gráficas. Este enfoque nos permitirá obtener una representación más intuitiva y visual de la distribución de la variable en cuestión, complementando así la información proporcionada por el resumen estadístico y el cálculo de la asimetría y la curtosis.

# %% [markdown]
# #### **Histogram**

# %% [markdown]
# La representación gráfica mediante un histograma nos permitirá visualizar la distribución de `price`. Esto nos proporcionará información visual sobre la forma de la distribución y posiblemente revelar patrones o comportamientos en los precios de alojamientos.

# %% [markdown]
# Aquí hay algunas de las principales características e información que se puede extraer de un histograma en el análisis univariado:
#
# * Forma de la distribución: El histograma mostrará la forma general de la distribución de los precios. Podemos identificar si sigue una distribución normal, si es asimétrica (sesgada a la izquierda o derecha) o tiene otra forma específica.
#
# * Centro de la distribución: Al observar el pico del histograma, podemos tener una idea visual del valor central alrededor del cual se agrupan los precios.
#
# * Dispersión y rango de precios: La dispersión de los precios se puede observar en la extensión horizontal del histograma. Un histograma más ancho indica una mayor variabilidad en los precios.
#
# * Identificación de modas (picos adicionales): Si hay varios picos en el histograma, podrían indicar la presencia de modas o agrupamientos específicos de precios (modalidad).
#
# * Detección de valores atípicos: Podemos identificar visualmente si hay valores atípicos (outliers) en los extremos del histograma.

# %%
# Visualizar la distribución de 'price' mediante un histograma

plt.hist(df['price'], bins=100, range=(0, 10000), color='skyblue', edgecolor='black')

# Lineas de mean y median
plt.axvline(df['price'].mean(), color='blue', linestyle='dashed', linewidth=1, label='Mean')
plt.axvline(df['price'].median(), color='green', linestyle='dashed', linewidth=1, label='Median')

# Etiquetas
plt.legend()
plt.xlabel('Price')
plt.ylabel('Count')
plt.title('Price Histogram', fontsize=12, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Price Histogram')

# %% [markdown]
# Podemos observar que el número de observaciones tiende a disminuir a medida que aumentan los valores de `price`. El histograma muestra una distribución asimétrica, sesgada hacia la derecha, con una concentración de observaciones en los valores más bajos y una disminución gradual a medida que los valores de `price` aumentan.
#
# En una distribución sesgada a la derecha como esta, la media tiende a ser mayor que la mediana debido a la influencia de los valores extremos en la cola derecha, tal como podemos observar en el histograma. Esto sucede porque la media es muy sensible a la presencia de valores extremos, mientras que la mediana, por otro lado, es la posición central de los datos ordenados y no se ve afectada por los valores extremos en la misma medida que la media.
#
# Este patrón sugiere que la mayoría de los precios de alojamientos están concentrados en la parte inferior de la escala horizontal, pero hay algunos casos excepcionales con precios significativamente más altos, indicados por la presencia de bins con frecuencias más bajas en la cola derecha del histograma. Estos bins de baja frecuencia sugieren la presencia de valores atípicos o extremos en esos rangos de precios. La distribución en general no es simétrica, mostrando una mayor variabilidad en los precios hacia la parte superior de la escala.
#
# Esta forma de distribución sesgada hacia la derecha es común en datos de precios, ya que es más probable encontrar precios más bajos que precios muy altos en general. En el contexto de alojamientos de Airbnb, es común encontrar una gran cantidad de alojamientos a precios asequibles, mientras que los precios muy altos son menos frecuentes y se consideran más exclusivos o lujosos.

# %% [markdown]
# #### **Boxplot**

# %% [markdown]
# Un diagrama de caja y bigotes o boxplot es otra herramienta gráfica que proporciona información valiosa sobre la distribución y la dispersión de una variable continua. Esta herramienta nos permitirá explorar la distribución de la variable `price` y nos proporcionará una representación gráfica intuitiva de la variabilidad y tendencia central de la variable en cuestión.

# %% [markdown]
# Aquí hay algunas de las principales características e información que se puede extraer de un boxplot en el análisis univariante:
#
# * Tendencia Central: La línea en el centro de la caja representa la mediana (segundo cuartil o Q2), proporcionando una medida de la tendencia central.
#
# * Dispersión y Rango Interquartílico (IQR): La longitud de la caja indica la dispersión de los datos en el rango intercuartílico (IQR), que es la diferencia entre el tercer y primer cuartil (Q3 - Q1).
#
# * Bigotes y Rango de Datos: Los bigotes indican la variabilidad total de los datos, extendiéndose hasta ciertos límites determinados por la regla 1.5 × IQR desde los cuartiles.
#
# * Identificación de Outliers: Los puntos individuales más allá de los bigotes se consideran valores atípicos o outliers, lo que proporciona una indicación visual de la presencia de datos inusuales o extremos.
#
# * Forma de la Distribución: La forma del boxplot puede dar pistas sobre la simetría o sesgo de la distribución. Por ejemplo, si la mediana está más cerca de un extremo de la caja, puede sugerir una distribución sesgada.
#
# * Comparación de Grupos: Se pueden crear boxplots para diferentes grupos o categorías y comparar visualmente sus distribuciones, lo que facilita la identificación de diferencias en tendencia central y dispersión.
#
# * Manejo de Outliers: La presencia de outliers en el boxplot permite una evaluación visual de su impacto en la distribución y ayuda a decidir si deben ser considerados en el análisis o tratados de manera especial.

# %%
# Visualizar la distribución de 'price' mediante un diagrama de caja

sns.boxplot(y='price', data=df, color='skyblue', linecolor='black')
plt.ylabel('Price')
plt.title('Price Boxplot', fontsize=12, fontweight='bold')
plt.show()

# %% [markdown]
# Debido a que tenemos valores extremos y una gran variabilidad en los datos, ajustaremos el rango en el eje Y para mejorar la legibilidad y reducir el impacto de los valores extremos en nuestra visualización. También realizaremos el calculo del rango intercuartílico para comprender mejor la dispersión de nuestros datos y agregaremos esas estadísticas en la visualización para proporcionar una referencia adicional sobre la variabilidad de los datos y los posibles valores atípicos o extremos.

# %%
# Visualizar la distribución de 'price' mediante un diagrama de caja

sns.boxplot(y='price', data=df, color='skyblue', linecolor='black')
plt.ylabel('Price')

# Calcular cuartiles
q1 = df['price'].quantile(.25)
q2 = df['price'].quantile(.5)
q3 = df['price'].quantile(.75)

# Calcular IQR
iqr = q3 - q1

# Calcular limite superior
upper_limit = q3 + 1.5 * iqr

# Añadir texto anotativo
plt.text(x=0.20, y=7000,
         s=f"Q1: {q1}\nQ2: {q2}\nQ3: {q3}\n\nIQR: {iqr}\nUpper Limit: {upper_limit}",
         color='black', fontsize=9, bbox=dict(facecolor='white', edgecolor='black', boxstyle='round'))

# EAjustar el rango del eje Y
plt.ylim(0, 10000)

# Añadir título
plt.title('Price Boxplot\n', fontsize=12, fontweight='bold')
plt.show()

# %% [markdown]
# El boxplot de la variable `price` revela una distribución sesgada hacia la derecha, donde la mediana se sitúa alrededor de 1,000, indicando que el 50% de los valores de `price`, es decir, el 50% de los listados se encuentran por debajo de este precio. La línea en el centro de la caja representa la mediana (segundo cuartil o Q2).
#
# La longitud de la caja indica la dispersión de los datos o la variabilidad en el centro de la distribución. La caja representa el rango intercuartílico (IQR) que abarca desde Q1 (639.75) hasta Q3 (1597.00). El 50% de los datos se encuentran dentro de este rango. Esto quiere decir que el 50% de los listados en nuestro conjunto de datos tienen un precio por noche de entre $639.75 y $1597.00.
#
# Los bigotes indican la variabilidad total de los datos, extendiéndose hasta ciertos límites determinados por la regla 1.5 × IQR desde los cuartiles Q3 y Q1. Estos límites indican la región dentro de la cual se espera que se encuentren la mayoría de los datos, y cualquier punto fuera de estos límites se consideraría un posible valor atípico o extremo. Podemos observar que los bigotes se extienden hasta 3032 (Upper Limit), siendo este el límite superior para identificación de posibles valores atípicos o extremos. Se observan puntos más allá de este límite, lo que indica la presencia de valores atípicos superiores en la distribución.

# %% [markdown]
# #### **Density Plot**

# %% [markdown]
# Un gráfico de densidad o density plot comparte información similar con un histograma, pero se presenta de una manera suave y continua. Al igual que en un histograma, la forma general del gráfico de densidad proporciona información sobre la distribución de los datos. Podemos identificar si la distribución es simétrica, sesgada a la derecha, sesgada a la izquierda, bimodal, etc.
#
# A diferencia de un histograma, no hay "bins" discretos en un gráfico de densidad. La suavidad de la curva proporciona una representación más continua de la distribución. Es especialmente útil cuando deseamos una visualización más suave y menos dependiente de la elección de los bins, como es el caso en un histograma. La forma de la curva y las áreas bajo ella proporcionan información clave sobre la distribución de la variable en cuestión.
#
# La curva en un gráfico de densidad representa una estimación suave de la función de densidad de probabilidad. La probabilidad de que una observación caiga en un rango particular está representada por el área bajo la curva dentro de ese rango. A diferencia del histograma, no hay divisiones discretas, la información es continua.
#
# Para ilustrar, si observamos el área bajo la curva entre dos valores específicos en el eje x, estamos viendo la probabilidad de que una observación caiga entre esos dos valores. Esto no cuenta los datos reales, sino que proporciona información sobre la probabilidad relativa de los diferentes valores.
#
# En resumen, el área bajo la curva en un gráfico de densidad es una representación visual de la probabilidad de que la variable aleatoria caiga dentro de ciertos intervalos, pero no se refiere directamente a la cantidad de datos observados en esos intervalos.

# %%
sns.kdeplot(df['price'], fill=True, color='skyblue', edgecolor='black', alpha=1)

plt.title('Price Density Graph', fontsize=12, fontweight='bold')
plt.xlabel('Price')
plt.ylabel('Densidad')

plt.xlim(0, 10000)

plt.show()

# %% [markdown]
# Hemos completado el análisis univariado de nuestra variable `price`. Durante este proceso, exploramos en detalle la distribución de precios de los alojamientos en la Ciudad de México mediante medidas estadísticas clave, visualizaciones como histogramas y boxplots, y evaluamos aspectos como la simetría, la concentración de datos y la presencia de valores atípicos. Este análisis univariado nos proporcionó una comprensión  de la naturaleza de nuestra variable `price`.
#
# A continuación exploraremos las relaciones entre nuestras variables categóricas y continuas con respecto a `price`. Este paso crucial nos permitirá identificar posibles patrones, correlaciones o influencias que puedan existir entre estas variables y nuestra variable de mayor interés. Lo que nos ayudará a responder las preguntas clave que intentamos resolver con nuestro analisis exploratorio de datos.

# %% [markdown]
# ### **Categorical Data Analysis**

# %% [markdown]
# En esta sección del análisis exploratorio de datos (EDA), nos enfocaremos en examinar las variables categóricas y su relación con la variable `price`. Comenzaremos por explorar la distribución y las frecuencias de las variables categóricas entre sí para identificar patrones o agrupaciones significativas. Además, evaluaremos cómo estas variables categóricas influyen en la variable `price` mediante análisis comparativos y visualizaciones que nos permitan entender mejor la relación entre ellas.
#
# Este análisis nos proporcionará información valiosa sobre cómo los diferentes atributos categóricos se relacionan y nos ayudará a identificar posibles factores influyentes en los precios de renta de alojamientos de Airbnb en la Ciudad de México.

# %% [markdown]
# En nuestro conjunto de datos tenemos varias variables categoricas, estas variables se pueden dividir en diferentes categorias o grupos y tienen valores discretos. Una forma de resumir y analizar estos datos categoricos es mediante la función `describe` y la función `value_counts`

# %%
# Resumen estadístico de las variable categóricas

df.describe(include= 'object')
# Out:
#                                  listing_url  host_name host_response_time  \
# count                                  16100      16100              16100
# unique                                 16100       2787                  4
# top     https://www.airbnb.com/rooms/1441434  Alejandra     within an hour
# freq                                       1        249              14466
#
#        host_is_superhost host_has_profile_pic host_identity_verified  \
# count              16100                16100                  16100
# unique                 2                    2                      2
# top                    t                    t                      t
# freq                8294                15910                  15954
#
#        neighbourhood        room_type
# count          16100            16100
# unique            16                4
# top       Cuauhtémoc  Entire home/apt
# freq            7994            11798

# %% [markdown]
# #### **Frequency Distribution**

# %% [markdown]
# El método `value_counts` se puede utilizar para determinar la cantidad de veces que aparece cada valor distinto de una variable categórica en un conjunto de datos. En términos estadísticos, esta es la "distribución de frecuencia" de la variable. El método `value_counts` genera una tabla con dos columnas. La primera columna contiene todos los valores distintos observados para la variable, los grupos o categorías unicas de cada variable. La segunda columna contiene la frecuencia de estos valores.
#
# A continuación mostramos la distribución de frecuencia de la variable `neighbourhood`, que es la variable que refleja la alcaldía donde se encuentran cada listado de nuestro conjunto de datos. Es decir, se mostrará la cantidad de listados o alojamientos que hay en cada alcaldía.

# %%
df['neighbourhood'].value_counts()
# Out:
# neighbourhood
# Cuauhtémoc                7994
# Miguel Hidalgo            2888
# Benito Juárez             1843
# Coyoacán                   933
# Venustiano Carranza        490
# Álvaro Obregón             471
# Tlalpan                    333
# Gustavo A. Madero          257
# Iztacalco                  256
# Cuajimalpa de Morelos      218
# Azcapotzalco               164
# Iztapalapa                 131
# Xochimilco                  47
# La Magdalena Contreras      39
# Tláhuac                     24
# Milpa Alta                  12
# Name: count, dtype: int64

# %% [markdown]
# Usando un bucle `for`, podemos calcular rápidamente la distribución de frecuencia de cada variable categórica y el porcentaje que representa cada grupo. En el cuerpo del bucle for, el método `value_counts()` nos dará la frecuencia de cada grupo o categoría en cada una de las columnas categóricas de nuestro DataFrame.

# %%
# Crear DataFrame unicamente con las variables categoricas.

categorical_columns = \
    df[['host_response_time', 'host_is_superhost', 'host_has_profile_pic', 'host_identity_verified', 'neighbourhood', 'room_type']]

categorical_columns.head(5)
# Out:
#    host_response_time host_is_superhost host_has_profile_pic  \
# 0      within an hour                 t                    t
# 1      within an hour                 t                    t
# 2  within a few hours                 t                    t
# 3      within an hour                 t                    t
# 4  within a few hours                 f                    t
#
#   host_identity_verified   neighbourhood        room_type
# 0                      t      Cuauhtémoc  Entire home/apt
# 1                      t  Miguel Hidalgo  Entire home/apt
# 2                      t      Cuauhtémoc     Private room
# 3                      t   Benito Juárez     Private room
# 4                      t      Cuauhtémoc  Entire home/apt

# %%
# Distribución de frecuencia de cada variable categorica

for column in categorical_columns.columns:
    print(" ")
    print(f"Variable: {column}")
    display(pd.concat([categorical_columns[column].value_counts(), \
                       (categorical_columns[column].value_counts()/len(categorical_columns)).round(3)], \
                        axis= 1, keys=['count', 'percent']).reset_index())
# Out:
#
# Variable: host_response_time
#    host_response_time  count  percent
# 0      within an hour  14466    0.899
# 1  within a few hours   1165    0.072
# 2        within a day    419    0.026
# 3  a few days or more     50    0.003
#
# Variable: host_is_superhost
#   host_is_superhost  count  percent
# 0                 t   8294    0.515
# 1                 f   7806    0.485
#
# Variable: host_has_profile_pic
#   host_has_profile_pic  count  percent
# 0                    t  15910    0.988
# 1                    f    190    0.012
#
# Variable: host_identity_verified
#   host_identity_verified  count  percent
# 0                      t  15954    0.991
# 1                      f    146    0.009
#
# Variable: neighbourhood
#              neighbourhood  count  percent
# 0               Cuauhtémoc   7994    0.497
# 1           Miguel Hidalgo   2888    0.179
# 2            Benito Juárez   1843    0.114
# 3                 Coyoacán    933    0.058
# ...

# %% [markdown]
# Podemos observar la cantidad de veces que aparece cada categoría única en nuestras variables categóricas y el porcentaje que representan. De este análisis de distribución de frecuencias utilizando el método `value_counts`, podemos extraer la siguiente información:

# %% [markdown]
# - **Variable: `host_response_time`**
#
# La mayoría de los anfitriones responden dentro de una hora, lo que representa aproximadamente el 89.9% del total de respuestas. Un pequeño porcentaje de anfitriones tarda algunas horas en responder (7.2%). Existe un grupo minoritario de anfitriones que responden dentro de un día o varios días, lo que puede afectar la experiencia de los huéspedes.

# %% [markdown]
# - **Variable: `host_is_superhost`**
#
# La mayoría de los anfitriones son superanfitriones (marcados como 't'), lo cual sugiere un alto nivel de calidad y satisfacción en la experiencia del huésped. Sin embargo, también es notable que hay una proporción considerable (48.5%) de anfitriones que no tienen la etiqueta de superanfitrión (marcados como 'f'), lo cual podría implicar algunas diferencias en la calidad o la experiencia ofrecida.
#
# - **Variable: `host_identity_verified`**
#
# La gran mayoría de los anfitriones (99.1%) tienen su identidad verificada ('t'), lo cual puede generar confianza y seguridad en los huéspedes al momento de reservar. Aunque es menos común, también existen anfitriones cuya identidad no está verificada ('f'), lo cual puede generar cierta precaución por parte de los huéspedes.

# %% [markdown]
# - **Variable: `neighbourhood`**
#
# La distribución de los alojamientos por alcaldía muestra que Cuauhtémoc es la más representada con 7,994, el 49.7% de los listados, seguida por Miguel Hidalgo (17.9%) y Benito Juárez (11.4%). Esto sugiere que estas áreas son populares entre los anfitriones y huespedes de Airbnb en la Ciudad de México. Al observar la distribución por alcaldía, podemos inferir patrones de preferencia y oferta en diferentes zonas de la ciudad, lo cual puede ser útil para entender la dinámica del mercado de alojamientos en Airbnb.

# %%
# Configurar estilo
sns.set_style("whitegrid")

sns.barplot(x= categorical_columns['neighbourhood'].value_counts(),
            y= categorical_columns['neighbourhood'].value_counts().index)

# Añadir las etiquetas de frecuencia en cada barra
for index, value in enumerate(df['neighbourhood'].value_counts()):
    plt.text(value + 100, index, str(value), ha='left', va='center', fontsize=10)

# Ocultar el eje x y las etiquetas
plt.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

# Título y etiquetas
plt.title('Alojamientos por Alcaldía \n', fontsize=12, fontweight='bold')
plt.xlabel(' \nNúmero de Alojamientos')
plt.ylabel('Alcaldía \n')
plt.show()

# %% [markdown]
# - **Variable: `room_type`**
#
# La mayoría de los alojamientos son casas o departamentos completos (73.3%), lo cual indica que hay una mayor oferta de alojamientos enteros y que los huéspedes prefieren reservar espacios enteros en lugar de habitaciones compartidas. Sin embargo, también existen opciones de habitaciones privadas (25.8%) y compartidas (0.8%), así como algunas habitaciones de hotel disponibles en la plataforma (0.2%), lo cual ofrece variedad en las opciones de alojamiento para los huéspedes.

# %%
# Configurar estilo
sns.set_style("whitegrid")

sns.barplot(x= categorical_columns['room_type'].value_counts(),
            y= categorical_columns['room_type'].value_counts().index)

# Añadir las etiquetas de frecuencia en cada barra
for index, value in enumerate(df['room_type'].value_counts()):
    plt.text(value + 100, index, str(value), ha='left', va='center', fontsize=10)

# Ocultar el eje x y las etiquetas
plt.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

# Título y etiquetas
plt.title('Tipos de Alojamiento \n', fontsize=12, fontweight='bold')
plt.xlabel(' \nNúmero de Alojamientos')
plt.ylabel('Tipo de Habitación \n')
plt.show()

# %% [markdown]
# Ahora realiremos un analisis de distribución del número de anfitriones y la cantidad de listados asociados a cada uno, esto nos permitirá obtener una visión general de la distribución de listados por anfitrion y entender mejor cómo están representados en la plataforma de Airbnb en la Ciudad de México. También dentificaremos el número de anfitriones que tienen un solo listado y aquellos que cuentan con más de un listado en la plataforma.

# %%
# Número de anfitriones en el conjunto de datos

print(f"Hay {df['host_id'].nunique()} Anfitriones en el conjunto de datos")
# Out:
# Hay 7413 Anfitriones en el conjunto de datos

# %%
# Anfitriones con mas listados en el conjunto de datos

host_count = df[['host_name', 'host_id']].value_counts().to_frame().reset_index()
display(host_count)
# Out:
#               host_name    host_id  count
# 0                 Mr. W   10764020    179
# 1                  Juan   16148871    123
# 2                  Clau  333035396     99
# 3                  HOMi   91265490     94
# 4             Alejandra  245618000     94
# ...                 ...        ...    ...
# 7408           Giuseppe   22420418      1
# 7409  Giulia Margherita   26966314      1
# 7410           Gisselle  533552914      1
# 7411           Gisselle  479953374      1
# 7412              Éríck  266108312      1
#
# [7413 rows x 3 columns]

# %% [markdown]
# El resultado anterior muestra la distribución del número de listados de Airbnb por anfitrión en el conjunto de datos. La tabla presenta una lista de nombres de anfitriones junto con su ID y la cantidad de listados que tienen en la plataforma, se pueden visualizar los anfitriones que cuentan con la mayor cantidad de listados.
#
# Los anfitriones con mayor número de listados son "Mr. W" con 179 listados, "Juan" con 123 listados, "Clau" con 99 listados, "HOMi" con 94 listados, y "Alejandra" también con 94 listados.

# %%
# Anfitriones con un listado vs anfitriones con mas de un listado

host_count['one_or_more_listings']= np.where(host_count['count'] > 1, "Más de un listado", "Un listado")
host_count
# Out:
#               host_name    host_id  count one_or_more_listings
# 0                 Mr. W   10764020    179    Más de un listado
# 1                  Juan   16148871    123    Más de un listado
# 2                  Clau  333035396     99    Más de un listado
# 3                  HOMi   91265490     94    Más de un listado
# 4             Alejandra  245618000     94    Más de un listado
# ...                 ...        ...    ...                  ...
# 7408           Giuseppe   22420418      1           Un listado
# 7409  Giulia Margherita   26966314      1           Un listado
# 7410           Gisselle  533552914      1           Un listado
# 7411           Gisselle  479953374      1           Un listado
# 7412              Éríck  266108312      1           Un listado
#
# [7413 rows x 4 columns]

# %%
# Configurar estilo
sns.set_style("whitegrid")

sns.barplot(x= host_count['one_or_more_listings'].value_counts(),
            y= host_count['one_or_more_listings'].value_counts().index)

# Añadir las etiquetas de frecuencia en cada barra
for index, value in enumerate(host_count['one_or_more_listings'].value_counts()):
    plt.text(value - 500, index, str(value), ha='left', va='center', fontsize=10, color='white')

# Ocultar el eje x y las etiquetas
plt.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

# Título y etiquetas
plt.title('Anfitriones con un listado \n vs Anfitriones con mas de un listado \n', fontsize=12, fontweight='bold')
plt.xlabel(' \nNúmero de Listados')
plt.ylabel('')
plt.show()

# %% [markdown]
# Podemos observar que hay 5109 anfitriones en la Ciudad de México que cuentan con un solo listado en la plataforma de Airbnb, mientras que 2304 anfitriones tienen más de un listado registrado.
#
# Esta información nos proporciona una comprensión clara de la distribución de los anfitriones en términos de la cantidad de listados que administran. Podemor determinar que una proporción significativa de anfitriones en la ciudad se dedica a una sola propiedad en la plataforma, mientras que un número considerable de anfitriones maneja múltiples propiedades.

# %% [markdown]
# ##### **Association Between Categorical Variables**

# %% [markdown]
# Para entender mejor la distribución de los tipos de alojamiento en cada alcaldía de la Ciudad de México, se realizará una tabla de contingencia (crosstab) para explorar la relación entre las variables `neighbourhood` y `room_type`, lo que nos permitirá entender la distribución de tipos de alojamiento en cada alcaldía y analizar la oferta de tipos de alojamientos en diferentes áreas de la Ciudad de México.
#
# Esta tabla de contingencia nos permitirá visualizar de manera clara y estructurada cuántos alojamientos de cada tipo (Entire home/apt, Hotel room, Private room, Shared room) se encuentran en cada una de los alcaldías analizadas. De esta manera, podremos identificar patrones de distribución de los distintos tipos de alojamiento.

# %%
# Crear tabla de contingencia

crosstab = pd.crosstab(df['neighbourhood'], df['room_type'], margins= True)
crosstab
# Out:
# room_type               Entire home/apt  Hotel room  Private room  \
# neighbourhood
# Azcapotzalco                        136           0            28
# Benito Juárez                      1203           4           630
# Coyoacán                            531           1           397
# Cuajimalpa de Morelos               179           1            36
# Cuauhtémoc                         6260          12          1639
# Gustavo A. Madero                   143           0           110
# Iztacalco                           151           1            98
# Iztapalapa                           76           0            54
# La Magdalena Contreras               25           0            14
# Miguel Hidalgo                     2259           5           617
# Milpa Alta                           11           0             1
# Tlalpan                             146           0           187
# Tláhuac                              18           0             5
# ...

# %% [markdown]
# Aquí hay algunas observaciones e información que se pueden extraer de este análisis:
#
# - **Preferencias de alojamiento por alcaldía:**
#
#     En Cuauhtémoc, hay una alta preferencia por alojamientos del tipo Entire home/apt y Private room, y una mayor preferencia por alojamientos del tipo Shared room que del tipo Hotel room. Mientras que en las demás alcaldías las preferencias entre estos dos últimos tipos de alojamientos es mas equilibrada.
#
# - **Diversidad de oferta:**
#
#     Algunas alcaldías muestran una mayor diversidad en la oferta de alojamientos, como Cuauhtémoc, Miguel Hidalgo y Benito Juárez, donde se encuentran representados todos los tipos de alojamiento en mayor proporcion que las demás alcaldías.
#
# - **Enfoque en ciertos tipos de alojamiento:**
#
#     Todas las alcaldías muestran una preferencia más marcada por ciertos tipos de alojamiento. Tienen una alta proporción de Entire home/apt y Private room en comparación con Hotel room y Shared room.

# %% [markdown]
# También se puede analizar y comparar la distribución relativa de cada tipo de alojamiento en las diferentes alcaldías para entender mejor las preferencias y la oferta en el mercado de alojamiento en la Ciudad de México. Para realizar este análisis crearemos una tabla de contingencia que muestre valores porcentuales en lugar de recuentos, en relación con el total de cada fila. Representando así, el porcentaje de cada tipo de alojamiento en relación a cada alcaldía.

# %%
# Crear tabla de contingencia con valores porcentuales

crosstab_with_percentage = pd.crosstab(df['neighbourhood'], df['room_type'], normalize= 'index')
crosstab_with_percentage
# Out:
# room_type               Entire home/apt  Hotel room  Private room  Shared room
# neighbourhood
# Azcapotzalco                   0.829268    0.000000      0.170732     0.000000
# Benito Juárez                  0.652740    0.002170      0.341834     0.003256
# Coyoacán                       0.569132    0.001072      0.425509     0.004287
# Cuajimalpa de Morelos          0.821101    0.004587      0.165138     0.009174
# Cuauhtémoc                     0.783087    0.001501      0.205029     0.010383
# Gustavo A. Madero              0.556420    0.000000      0.428016     0.015564
# Iztacalco                      0.589844    0.003906      0.382812     0.023438
# Iztapalapa                     0.580153    0.000000      0.412214     0.007634
# La Magdalena Contreras         0.641026    0.000000      0.358974     0.000000
# Miguel Hidalgo                 0.782202    0.001731      0.213643     0.002424
# Milpa Alta                     0.916667    0.000000      0.083333     0.000000
# ...

# %% [markdown]
# Ahora utilizaremos estos valores porcentuales para crear un gráfico de barras apilado que visualice la distribución de los diferentes tipos de alojamiento en cada alcaldía de la Ciudad de México. Este gráfico nos permitirá comparar de manera efectiva la distribución relativa y las preferencias de cada tipo de alojamiento dentro de cada alcaldía. Además, al ser un gráfico apilado, podremos observar la contribución de cada tipo de alojamiento al total de alojamientos en cada alcaldía, brindando una perspectiva clara de la estructura del mercado de alojamientos en la ciudad.

# %%
# Crear gráfico de barras apilado

crosstab_with_percentage.plot(kind="barh", stacked=True)
plt.title("Distribución relativa de los tipos de alojamiento por alcaldía\n", fontsize=12, fontweight='bold')
plt.xlabel("\nPorcentaje Tipos de Alojamiento")
plt.ylabel("Alcaldía\n")
# Out:
# Text(0, 0.5, 'Alcaldía\n')

# %% [markdown]
# Al analizar la distribución relativa de los tipos de alojamientos en cada alcaldía, podemos obtener información relevante sobre las preferencias de alojamiento y la oferta en diferentes áreas de la Ciudad de México:
#
# - **Dominancia de alojamientos enteros:**
#
#     En todas las alcaldías los alojamientos enteros (Entire home/apt) son predominantemente mas ofertados en comparación con otros tipos de alojamientos. Esto podría sugerir una demanda significativa por alojamientos completos, posiblemente debido a preferencias de privacidad o comodidad para grupos o familias. Solo en Tlalpan las habitaciones privadas ocupan una mayor proporción que los alojamientos enteros
#
# - **Preferencia por habitaciones privadas:**
#
#     Algunas alcaldías como Coyoacán, Iztacalco, Iztapalapa, Gustavo A. Madero y Tlalpan muestran una proporción notablemente alta de alojamientos de tipo habitación privada (Private room). Esto podría indicar una demanda específica por espacios más íntimos o asequibles para viajeros individuales o parejas en estas áreas.
#
# - **Variabilidad en alojamientos compartidos:**
#
#     Si bien los alojamientos compartidos (Shared room) no son tan comunes en general, se observa una mayor proporción en algunas alcaldías como Gustavo A. Madero, Tláhuac e Iztacalco. Esto puede reflejar una demanda de alojamientos económicos para viajeros que prefieren compartir espacios con otros huéspedes.
#
# - **Oferta de hoteles:**
#
#     La presencia de alojamientos tipo Hotel room es bastante baja en general, lo que sugiere que la oferta de alojamiento en formato hotelero es menos común en comparación con las opciones de alojamiento privado o compartido ofrecidas en plataformas como Airbnb.

# %% [markdown]
# La distribución de los tipos de alojamiento en cada alcaldía nos proporciona información valiosa sobre la oferta de alojamiento en esas áreas específicas. Esta información puede ser útil para entender la estructura del mercado de alojamiento en la Ciudad de México, para entender la diversidad de opciones disponibles para los huéspedes, la distribución de los diferentes tipos de alojamiento en la ciudad y para evaluar la capacidad del mercado para satisfacer diferentes preferencias de los viajeros.

# %% [markdown]
# #### **Data Grouping**

# %% [markdown]
# El Data Grouping o Agrupamiento de Datos es una técnica utilizada en análisis de datos para organizar y estructurar la información en conjuntos o grupos basados en ciertas características o criterios comunes, para luego realizar cálculos o análisis dentro de esos grupos. Esto se hace con el objetivo de facilitar el análisis y la interpretación de los datos al identificar patrones, tendencias o relaciones dentro de cada grupo.
#
# En nuestro proyecto, el agrupamiento de datos puede aplicarse a variables categóricas o numéricas para generar insights significativos. Por ejemplo, en el análisis de precios de alojamientos de Airbnb en la Ciudad de México, podemos agrupar los alojamientos por tipo de habitación (como casa completa, habitación privada, habitación compartida) o por ubicación (por alcaldía o zona de la ciudad), lo que permitiría realizar comparaciones y extraer conclusiones más específicas sobre cada grupo.

# %% [markdown]
# En Python, la biblioteca Pandas proporciona el método `groupby()` que es muy útil para realizar operaciones de agrupación en un DataFrame. El método `groupby` agrupa los datos por diferentes categorías. Los datos se agrupan en función de una o varias variables y el análisis se realiza en los grupos individuales.
#
# Podemos conocer la distribución de la variable `price` en función de las categorías de una variable categórica utilizando `groupby` y `mean()` para calcular la media de `price` para cada grupo individual.

# %% [markdown]
# A continuación, agruparemos los alojamientos por alcaldía (`neighbourhood`) y calcularemos la media de los precios en cada grupo. Esta acción nos permitirá identificar y comparar los precios medios de alojamiento en las diferentes alcaldías de la Ciudad de México. Posteriormente, ordenaremos estos resultados de manera descendente para destacar las alcaldías que presentan los precios promedio más altos en el mercado de Airbnb de la Ciudad de México.

# %%
df.groupby('neighbourhood', as_index= False)['price'].mean().round(2) \
    .sort_values(by= 'price', ascending= False).reset_index(drop= True)
# Out:
#              neighbourhood    price
# 0           Miguel Hidalgo  1708.17
# 1               Cuauhtémoc  1594.96
# 2    Cuajimalpa de Morelos  1324.94
# 3           Álvaro Obregón  1099.94
# 4               Xochimilco  1080.04
# 5                 Coyoacán  1027.00
# 6            Benito Juárez   969.82
# 7               Milpa Alta   953.42
# 8   La Magdalena Contreras   885.97
# 9                  Tlalpan   837.74
# 10               Iztacalco   792.88
# 11     Venustiano Carranza   750.28
# 12            Azcapotzalco   730.79
# 13       Gustavo A. Madero   698.62
# 14              Iztapalapa   616.76
# 15                 Tláhuac   396.79

# %% [markdown]
# Los resultados muestran el precio medio de alojamientos en cada alcaldía de la Ciudad de México. Estos valores representan un promedio de los precios de alojamiento por noche en cada área específica. Al analizar estos datos, podemos observar diferencias significativas en los precios entre las diferentes alcaldías.
#
# * Miguel Hidalgo, con un precio medio de $1708.17, muestra una tendencia hacia alojamientos más costosos en comparación con otras áreas. Cuauhtémoc, con un precio medio de $1594.87, también presenta precios relativamente altos en alojamientos, aunque ligeramente inferiores a los de Miguel Hidalgo. Las posiciones de la alcaldía Cuauhtémoc y Miguel Hidalgo se podrían explicar por abarcar la zona centro de la CDMX. Cuajimalpa de Morelos, con un precio medio de $1324.94, se encuentra en un rango intermedio en términos de precios de alojamientos.
#
# * Iztapalapa, con un precio medio de $616.76, representa una de las opciones más económicas en cuanto a alojamientos en la Ciudad de México. Tláhuac, con un precio medio de $396.79, muestra precios aún más bajos en comparación con las demás alcaldías, siendo una opción a considerar para aquellos con un presupuesto limitado.
#
# Estos resultados son útiles para entender la distribución de precios de alojamientos de Airbnb en la Ciudad de México y pueden ser de interés para viajeros que buscan opciones de alojamiento dentro de un determinado presupuesto o área geográfica específica.

# %%
# Configurar estilo
sns.set_style("whitegrid")

# Agrupar variables a analizar
mean_price_by_neighbourhood = df.groupby('neighbourhood', as_index= False)['price'].mean().round(2) \
    .sort_values(by= 'price', ascending= False).reset_index(drop= True)

# Configurar gráfico
sns.barplot(x= 'price', y= 'neighbourhood',
            data= mean_price_by_neighbourhood)

# Añadir etiquetas en cada barra
for index, value in enumerate(mean_price_by_neighbourhood['price']):
    plt.text(value + 50, index, f'${value:.2f}', ha='left', va='center', fontsize=10)

# Ocultar el eje x y las etiquetas
plt.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

# Título y etiquetas
plt.title('Precio Medio por Alcaldía en la CDMX \n', fontsize=12, fontweight='bold')
plt.xlabel(' \nPrecio Medio')
plt.ylabel('Alcaldía \n')
plt.show()

# %% [markdown]
# Esta información también brinda a los anfitriones una visión del mercado de alojamientos en la Ciudad de México.  Al conocer el precio medio de alojamientos en cada alcaldía, los anfitriones pueden ajustar sus tarifas para ser más competitivos en el mercado. Además, les ayuda a comprender las preferencias y demandas de los viajeros en diferentes áreas de la ciudad, lo que les permite adaptar sus estrategias de precios y de marketing para resaltar las características únicas de sus alojamientos, ya sea enfocándose en la calidad, la ubicación o el valor por el precio.

# %% [markdown]
# Usando un bucle for podemos agrupar las categorías de cada columna categoríca de nuestro DataFrame. Utilizamos los métodos `groupby()` y `mean()` en el cuerpo del bucle for para conocer la distribución del precio en las categorías o grupos de cada columna.

# %%
for column in categorical_columns.columns:
    print(" ")
    print('Variable:', column)
    display(df.groupby(column, as_index= False)['price'].mean().round(2) \
    .sort_values(by= 'price', ascending= False).reset_index(drop= True))
# Out:
#
# Variable: host_response_time
#    host_response_time    price
# 0      within an hour  1435.43
# 1  within a few hours  1127.98
# 2        within a day  1060.64
# 3  a few days or more   969.58
#
# Variable: host_is_superhost
#   host_is_superhost    price
# 0                 t  1567.02
# 1                 f  1226.61
#
# Variable: host_has_profile_pic
#   host_has_profile_pic    price
# 0                    t  1405.94
# 1                    f  1070.15
#
# Variable: host_identity_verified
#   host_identity_verified    price
# 0                      f  1873.24
# 1                      t  1397.67
#
# Variable: neighbourhood
#              neighbourhood    price
# 0           Miguel Hidalgo  1708.17
# 1               Cuauhtémoc  1594.96
# 2    Cuajimalpa de Morelos  1324.94
# 3           Álvaro Obregón  1099.94
# 4               Xochimilco  1080.04
# 5                 Coyoacán  1027.00
# 6            Benito Juárez   969.82
# 7               Milpa Alta   953.42
# ...

# %% [markdown]
# De este analisis de precios por grupos podemos extraer la siguiente información.

# %% [markdown]
# - **`host_response_time`**
#
# Los alojamientos con tiempo de respuesta dentro de una hora tienen el precio medio más alto, con un promedio de $1435.43. Aquellos cuyas respuestas tardan algunas horas tienen un precio medio de $1127.98 en promedio. Esto sugiere que hay una relación entre el tiempo de respuesta de los anfitriones y los precios de los alojamientos. Los alojamientos con respuestas rápidas tienden a tener precios medios mas altos.
#
# - **`host_is_superhost`**
#
# Los alojamientos de anfitriones con la distinción superhost tienen un precio medio ($1567.02) mas alto de  en comparación con aquellos sin esta distinción ($1226.61), posiblemente debido a la reputación y confianza asociadas con los superanfitriones.
#
# - **`host_has_profile_pic`**
#
# Los alojamientos con anfitriones que tienen una foto de perfil tienen un precio medio de $1405.94 en promedio. Los alojamientos con anfitriones que no tienen una foto de perfil tienen un precio medio más bajo, con $1070.15 en promedio.  La presencia de una foto de perfil del anfitrión puede estar asociada con factores como confianza, transparencia, hospitalidad o percepción de calidad, todos los cuales pueden contribuir a precios medios más altos para los alojamientos.
#
# - **`host_identity_verified`**
#
# Los alojamientos sin verificación de identidad (f) tienen un precio medio más alto en comparación con aquellos con verificación (t), Esto indica una interesante tendencia donde, en promedio, los alojamientos sin verificación de identidad tienen precios más altos que aquellos con verificación. Esto podría deberse a varios factores, como la exclusividad, la calidad percibida y la demanda de alojamientos sin verificación de identidad, lo que puede sugerir que los huéspedes están dispuestos a pagar más por ciertos tipos de alojamientos a pesar de la falta de verificación de identidad del anfitrión.

# %% [markdown]
# - **`room_type`**
#
# Los alojamientos de tipo "Entire home/apt" y "Hotel room" tienen precios medios significativamente más altos que "Private room" y "Shared room", lo cual es coherente con la idea de que alojarse en un espacio completo o en un hotel tiende a ser más costoso que compartir espacio con otros huéspedes.

# %%
# Configurar estilo
sns.set_style("whitegrid")

# Agrupar variables a analizar
mean_price_by_room_type = df.groupby('room_type', as_index= False)['price'].mean().round(2) \
    .sort_values(by= 'price', ascending= False).reset_index(drop= True)

# Configurar gráfico
sns.barplot(x= 'price', y= 'room_type',
            data= mean_price_by_room_type)

# Añadir etiquetas en cada barra
for index, value in enumerate(mean_price_by_room_type['price']):
    plt.text(value + 50, index, f'${value:.2f}', ha='left', va='center', fontsize=10)

# Ocultar el eje x y las etiquetas
plt.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)

# Título y etiquetas
plt.title('Precio Medio por Tipo de Alojamiento \n', fontsize=12, fontweight='bold')
# Subtitulo: plt.text(0.5, 1, 'Subtítulo del Gráfico', fontsize=12, weight='normal', color='blue', ha='center', va='bottom', transform=plt.gca().transAxes)
plt.xlabel(' \nPrecio Medio')
plt.ylabel('Tipo de Alojamiento \n')
plt.show()

# %% [markdown]
# ##### **Grouping Data by Multiple Variables**

# %% [markdown]
# Ahora nos adentraremos en el agrupamiento de datos por múltiples variables. Esto nos permitirá explorar cómo se comportan los precios en función de diversas características, brindándonos una perspectiva más detallada de los factores que influyen en los precios de alojamiento.

# %% [markdown]
# Agruparemos los datos por alcaldía y tipo de alojamiento para calcular el precio medio de los alojamientos en cada combinación de estas variables. Esto nos proporcionará una visión detallada de cómo varían los precios según la ubicación y el tipo de alojamiento, lo que nos permitirá identificar patrones y tendencias significativas en los precios de hospedaje en diferentes áreas y tipos de propiedades.

# %%
# Agrupar variables a analizar

df.groupby(['neighbourhood', 'room_type'])['price'].mean().round(2).reset_index()# \
   # .sort_values(by= 'price', ascending= False).reset_index()
# Out:
#              neighbourhood        room_type    price
# 0             Azcapotzalco  Entire home/apt   789.97
# 1             Azcapotzalco     Private room   443.32
# 2            Benito Juárez  Entire home/apt  1162.78
# 3            Benito Juárez       Hotel room   910.25
# 4            Benito Juárez     Private room   608.50
# 5            Benito Juárez      Shared room   260.33
# 6                 Coyoacán  Entire home/apt  1336.07
# 7                 Coyoacán       Hotel room  2836.00
# 8                 Coyoacán     Private room   615.24
# 9                 Coyoacán      Shared room   413.25
# 10   Cuajimalpa de Morelos  Entire home/apt  1447.58
# 11   Cuajimalpa de Morelos       Hotel room  2123.00
# 12   Cuajimalpa de Morelos     Private room   715.56
# 13   Cuajimalpa de Morelos      Shared room   918.00
# 14              Cuauhtémoc  Entire home/apt  1842.11
# 15              Cuauhtémoc       Hotel room  1296.83
# 16              Cuauhtémoc     Private room   716.42
# ...

# %% [markdown]
# Estos datos agrupados son mucho más fáciles de visualizar cuando se convierten en una tabla dinámica o pivot table. Podemos convertir el DataFrame en una tabla dinámica usando el método `pivot()` para crear una tabla dinámica a partir de los grupos de cada variable.

# %%
# Crear pivot table

grouped_pivot = df.groupby(['neighbourhood', 'room_type'])['price'].mean().round(2).reset_index(). \
    pivot(index='neighbourhood',columns='room_type', values= 'price').fillna(0)

display(grouped_pivot)
# Out:
# room_type               Entire home/apt  Hotel room  Private room  Shared room
# neighbourhood
# Azcapotzalco                     789.97        0.00        443.32         0.00
# Benito Juárez                   1162.78      910.25        608.50       260.33
# Coyoacán                        1336.07     2836.00        615.24       413.25
# Cuajimalpa de Morelos           1447.58     2123.00        715.56       918.00
# Cuauhtémoc                      1842.11     1296.83        716.42       346.10
# Gustavo A. Madero                897.82        0.00        457.47       209.00
# Iztacalco                        922.73      921.00        603.41       598.33
# Iztapalapa                       695.09        0.00        508.87       490.00
# La Magdalena Contreras          1029.56        0.00        629.57         0.00
# Miguel Hidalgo                  1970.98     1619.20        761.01       443.00
# Milpa Alta                      1003.73        0.00        400.00         0.00
# ...

# %%
# Ordenar correctamente nombre de alcaldías

grouped_pivot = grouped_pivot.reindex([
    'Álvaro Obregón', 'Azcapotzalco', 'Benito Juárez', 'Coyoacán', 'Cuajimalpa de Morelos',
    'Cuauhtémoc', 'Gustavo A. Madero', 'Iztacalco', 'Iztapalapa',
    'La Magdalena Contreras', 'Miguel Hidalgo', 'Milpa Alta', 'Tlalpan',
    'Tláhuac', 'Venustiano Carranza', 'Xochimilco'
])

display(grouped_pivot)
# Out:
# room_type               Entire home/apt  Hotel room  Private room  Shared room
# neighbourhood
# Álvaro Obregón                  1349.99     1482.67        573.56       535.25
# Azcapotzalco                     789.97        0.00        443.32         0.00
# Benito Juárez                   1162.78      910.25        608.50       260.33
# Coyoacán                        1336.07     2836.00        615.24       413.25
# Cuajimalpa de Morelos           1447.58     2123.00        715.56       918.00
# Cuauhtémoc                      1842.11     1296.83        716.42       346.10
# Gustavo A. Madero                897.82        0.00        457.47       209.00
# Iztacalco                        922.73      921.00        603.41       598.33
# Iztapalapa                       695.09        0.00        508.87       490.00
# La Magdalena Contreras          1029.56        0.00        629.57         0.00
# Miguel Hidalgo                  1970.98     1619.20        761.01       443.00
# ...

# %% [markdown]
# Ahora que hemos creado nuestra pivot table que muestra el precio medio de tipos de alojamiento por alcaldía, vamos a utilizar estos datos para crear un mapa de calor. Un Mapa de calor o Heat map es una forma efectiva de visualizar la relación entre dos variables categóricas y una variable continua utilizando colores para representar los valores de la variable continua. Este tipo de gráfico es útil cuando queremos analizar la tendencia o patrón de una variable numérica en función de dos variables categóricas.
#
# Este mapa nos permitirá visualizar de manera más intuitiva y detallada cómo varían los precios según el tipo de alojamiento y la ubicación en cada alcaldía, proporcionándonos una visión mas completa de la distribución de precios en la Ciudad de México.

# %%
# Crear el HeatMap con Seaborn
sns.heatmap(grouped_pivot, cmap='Blues', cbar= True, annot=True, annot_kws={"fontsize": 8},  fmt=".2f", linewidths=0)

# Agregar etiquetas a los ejes
plt.xlabel(' \nTipo de Alojamiento')
plt.ylabel('Alcaldía\n ')

plt.title('Heatmap de Precios Medios por Tipo de Alojamiento y Alcaldía\n', fontsize=12, fontweight='bold')
plt.show()

# %% [markdown]
# Al observar el heatmap de los precios medios de tipos de alojamiento por alcaldía, algunas relaciones importantes que se destacan son:
#
# - **Diferencias de precios por tipo de alojamiento:**
#
#     Se puede notar claramente que los precios varían significativamente según el tipo de alojamiento. Por ejemplo, en Cuauhtemóc, los precios medios para Entire home/apt son más altos que para Private room y Shared room, mientras que en Álvaro Obregón, los precios para Hotel room son más altos que para otros tipos de alojamiento.
#
# - V**ariaciones de precios por alcaldía:**
#
#     Se observan diferencias considerables en los precios medios entre las alcaldías. Por ejemplo, en Miguel Hidalgo y Cuauhtémoc, los precios para Entire home/apt son bastante altos en comparación con otras alcaldías como Iztapalapa o Tláhuac, donde los precios son más bajos en general.
#
# - **Distribución de tipos de alojamiento:**
#
#     Algunas alcaldías tienen una distribución variada de tipos de alojamiento, como Benito Juárez y Coyoacán, donde se encuentran diferentes tipos de alojamiento con precios variados. Mientras tanto, en algunas alcaldías como Milpa Alta, la oferta de ciertos tipos de alojamiento puede ser limitada o inexistente.
#
# - **Patrones de demanda y oferta:**
#
#     Los precios medios reflejan posiblemente la demanda y la oferta de alojamientos en cada alcaldía. Algunas alcaldías pueden tener una mayor demanda de ciertos tipos de alojamiento, lo que influye en los precios promedio.

# %% [markdown]
# ### **Numerical Data Analysis**

# %% [markdown]
# En esta sección, nos adentraremos en el análisis de variables numéricas para comprender mejor la relación entre nuestras variables numéricas y el precio de los alojamientos en el mercado de Airbnb en la Ciudad de México. Mediante este análisis, exploraremos cómo se relacionan factores como el número de reviews, las puntuaciones de las reviews, el número de habitaciones y baños, entre otras características, con los precios de los alojamientos.
#
# Se emplearán técnicas de análisis de correlación para evaluar la fuerza y dirección de las relaciones entre estas variables numéricas y el precio de los alojamientos. Además, se utilizarán visualizaciones gráficas como scatterplots (gráficos de dispersión) y mapas de calor para representar visualmente estas relaciones e identificar patrones y tendencias que puedan ayudarnos a entender qué factores tienen mayor influencia en los precios y cómo se distribuyen estos precios en función de las diferentes variables.
#
# El objetivo principal de este análisis es obtener insights sobre cómo las variables numéricas influyen en el precio de los alojamientos en la Ciudad de México, lo que proporcionará una comprensión más profunda del mercado y permitirá identificar factores clave que impactan en los precios de los alojamientos en esta plataforma.

# %% [markdown]
# Las variables numéricas pueden ser de tipo "int64" o "float64". Usamos la función `describe` en nuestro conjunto de datos para obtener un resumen estadístico de este tipo de variables.
#
# Este resumen estadístico incluye: el número de observaciones no nulas para cada variable, la media aritmética que representa el valor promedio, la desviación estándar que mide la dispersión de los datos alrededor de la media, así como los valores mínimo y máximo que delimitan el rango de la variable.
#
# Además, nos presenta información sobre los cuartiles, incluyendo el primer cuartil (25%), la mediana (50%), y el tercer cuartil (75%), ofreciendo una perspectiva detallada de la tendencia central y la dispersión de los datos.

# %%
df.describe()
# Out:
#                  id       host_id                     host_since  \
# count  1.610000e+04  1.610000e+04                          16100
# mean   4.579628e+17  2.058479e+08  2018-03-03 03:02:55.091620608
# min    6.179200e+04  7.365000e+03            2009-02-03 00:00:00
# 25%    3.995415e+07  5.008231e+07            2015-12-10 00:00:00
# 50%    6.150000e+17  1.496837e+08            2017-09-08 00:00:00
# 75%    8.750000e+17  3.596119e+08            2020-07-30 06:00:00
# max    1.050000e+18  5.505917e+08            2023-12-11 00:00:00
# std    4.281602e+17  1.748132e+08                            NaN
#
#        host_response_rate  host_acceptance_rate      latitude     longitude  \
# count        16100.000000          16100.000000  16100.000000  16100.000000
# mean             0.982283              0.964239     19.408764    -99.165820
# min              0.000000              0.000000     19.178144    -99.339630
# ...

# %% [markdown]
# Estas estadísticas nos proporcionan una visión general de la distribución, tendencia central y variabilidad de cada variable continua en nuestro conjunto de datos, proporcionando una base para el analisis de nuestras variables continuas.

# %% [markdown]
# #### **Correlation Analysis**

# %% [markdown]
# El análisis de correlación es una técnica estadística que se utiliza para evaluar la relación entre dos o más variables numéricas. Su objetivo principal es determinar si existe una asociación entre las variables y en qué medida se relacionan, en este caso, entre nuestras variables continuas como la cantidad de huéspedes que permite el anfitrion, el número de habitaciones, camas, baños, etc., y el precio de alquiler de los alojamientos.
#
# El análisis de correlación proporciona un valor numérico llamado coeficiente de correlación, denotado como r, el coeficiente de correlación es la medida que cuantifica la fuerza y la dirección de una relación lineal entre dos variables. En otras palabras, cuando observamos dos variables, si una variable cambia, ¿cómo afecta esto al cambio en la otra variable? Cuando dos variables están correlacionadas positivamente, significa que tienden a cambiar en la misma dirección, es decir, cuando una variable aumenta, la otra también tiende a aumentar. Por otro lado, si las variables están correlacionadas negativamente, significa que tienden a cambiar en direcciones opuestas; cuando una variable aumenta, la otra tiende a disminuir.
#
# El coeficiente de correlación puede tomar un rango de valores entre -1 y 1 inclusive, donde:
#
# El valor absoluto del coeficiente de correlación de Pearson |r| indica la fuerza de la asociación.
#
# * Si |r| está cerca de 1, la correlación es fuerte entre las variables.
# * Si |r| está cerca de 0, la correlación es débil o inexistente entre las variables.
#
# El signo de r indica la dirección de la asociación.
#
# * Si r > 0 indica una correlación positiva
# * Si r < 0 indica una correlación inversa o negativa
#
# Entonces:
#
# * Si **r = 1:** Correlación lineal positiva perfecta.
# * Si **r = 0:** Sin correlación lineal, lo más probable es que las dos variables no se afecten entre sí.
# * Si **r = -1:** Correlación lineal negativa perfecta.

# %% [markdown]
# Al realizar el análisis de correlación, se buscarán relaciones significativas entre las variables numéricas y el precio de los alojamientos. Un coeficiente de correlación cercano a 1 o -1 indicaría una fuerte asociación lineal entre las variables, lo que podría indicar que esa variable tiene un impacto considerable en el precio de los alojamientos. Por otro lado, un coeficiente de correlación cercano a 0 sugeriría una relación débil o nula entre las variables.
#
# Este análisis de correlación roporcionará insights sobre qué variables numericas tienen una relación más estrecha con el precio de los alojamientos en la Ciudad de México, lo que ayudará a comprender mejor los factores que influyen en los precios de los alojamientos en este mercado.

# %% [markdown]
# Para calcular el coeficiente de correlación entre la variable `price` y las variables numéricas de nuestro conjunto de datos, se empleará el método `corr()`. La correlación de Pearson es el método predeterminado utilizado por esta función.

# %%
# Crear DataFrame unicamente con las variables numricas de nuestro conjunto de datos

numerical_columns = df.select_dtypes(include= 'number')
numerical_columns = numerical_columns.drop(columns= ['latitude', 'longitude'], errors='ignore')
numerical_columns.head(5)
# Out:
#           id  host_id  host_response_rate  host_acceptance_rate  accommodates  \
# 0  1441434.0  7740056                 1.0                  1.00             2
# 1  1462549.0  7838265                 1.0                  0.99             2
# 2    61792.0   299558                 1.0                  1.00             2
# 3  1476127.0  7900007                 1.0                  0.98             2
# 4    67703.0   334451                 1.0                  0.57             4
#
#    bedrooms  bathrooms  beds   price  minimum_nights  maximum_nights  \
# 0         1        1.5     1  3350.0               9             380
# 1         1        2.0     2  1002.0               3            1125
# 2         1        1.0     1  1018.0               2            1125
# 3         1        1.0     1   950.0               1             365
# 4         2        1.0     2  1794.0               4              30
#
#    number_of_reviews  review_scores_rating  review_scores_accuracy  \
# ...

# %%
correlation_table = numerical_columns.corr()['price'] \
    .reset_index().rename(columns={'index': 'variable', 'price': 'r'})
display(correlation_table)
# Out:
#                           variable         r
# 0                               id  0.073084
# 1                          host_id -0.028985
# 2               host_response_rate  0.048437
# 3             host_acceptance_rate  0.059294
# 4                     accommodates  0.549023
# 5                         bedrooms  0.596123
# 6                        bathrooms  0.539868
# 7                             beds  0.511588
# 8                            price  1.000000
# 9                   minimum_nights  0.014700
# 10                  maximum_nights  0.008530
# 11               number_of_reviews -0.045345
# 12            review_scores_rating  0.055131
# 13          review_scores_accuracy  0.014661
# 14       review_scores_cleanliness  0.075141
# 15           review_scores_checkin  0.034365
# 16     review_scores_communication  0.032846
# 17          review_scores_location  0.094124
# 18             review_scores_value  0.023392
# 19  calculated_host_listings_count  0.150976
# ...

# %% [markdown]
# Visualizamos esta información en un mapa de calor para comprender mejor cómo se relaciona el precio de los alojamientos con las demás variables numéricas en nuestro conjunto de datos. Al observar el mapa de calor, podemos identificar patrones de correlación que nos ayudan a entender qué características tienen una mayor influencia en el precio de los alojamientos. Las áreas con colores más intensos, ya sea en tonos cálidos o fríos, indican una correlación más fuerte, mientras que las áreas cercanas al blanco reflejan una correlación más débil o cercana a cero.

# %%
plt.figure(figsize=(16, 6))
sns.heatmap(numerical_columns.corr(), annot=True, cmap= 'coolwarm', linewidths=0.5, vmax= 1, vmin= -1)
# Out:
# <Axes: >

# %% [markdown]
# Del análisis de correlación realizado entre las variables numéricas y el precio de los alojamientos podemos obtener varias observaciones importantes.

# %% [markdown]
# ##### **Variables más correlacionadas positivamente.**
#
# Las variables con correlaciones positivas más fuertes con el precio son el número de habitaciones (`bedrooms`), el número de baños (`bathrooms`), el número de huespedes posible (`accommodates`) y la cantidad de camas (`beds`). Esto sugiere que a medida que estas variables aumentan, es probable que el precio de los alojamientos también aumente.
#
# El hecho de que estas variables tengan correlaciones positivas mas fuertes con el precio de renta puede ser debido a su impacto directo en la experiencia y la comodidad de los huéspedes. Por ejemplo, el número de habitaciones y baños influye en la capacidad para acomodar a más personas y proporcionar comodidades adicionales, lo que aumenta la percepción de valor y justifica un precio más alto. Del mismo modo, la capacidad de alojamiento, representada por el número de huéspedes posibles y camas disponibles, refleja la capacidad del alojamiento para atender a grupos grandes, lo que también influye en su precio.
#
# Alojamientos con más habitaciones, baños, mayor capacidad de huéspedes y mas camas disponibles tienden a tener precios más altos, lo cual es coherente con la idea de que propiedades más grandes, con más comodidades o con un mayor número de huéspedes permitidos suelen ser más costosas.
#
# La correlación positiva entre estas variables y el precio indica que son factores importantes que influyen en el precio los alojamientos en el mercado de la Ciudad de México.

# %%
plt.figure(figsize=(4, 6))

# Crear el HeatMap con Seaborn
sns.heatmap(numerical_columns.corr().sort_values(by= 'price', ascending= False).loc[:, ['price']], cmap= 'coolwarm', linewidths=0, cbar= True, \
            annot=True, annot_kws={"fontsize": 9}, fmt=".2f", vmax= 1, vmin= -1)

# Agregar etiquetas a los ejes
plt.xlabel(' \nCoeficiente de correlación')
plt.ylabel('Variables Continuas\n ')

plt.title('Correlation Heatmap\n', fontsize=12, fontweight='bold')
plt.show()

# %% [markdown]
# ##### **Impacto de las puntuaciones de reseñas.**
#
# En la plataforma de Airbnb, hay varios tipos de puntuaciones de reseñas que los huéspedes pueden utiliza para evaluar y ayudar a valorar cada listado. ¿Estas puntuaciones de las reseñas se correlacionan con el precio de alquiler? Miremos más de cerca.

# %%
plt.figure(figsize=(8, 4))
sns.heatmap(numerical_columns[['review_scores_rating',
       'review_scores_accuracy', 'review_scores_cleanliness',
       'review_scores_checkin', 'review_scores_communication',
       'review_scores_location', 'review_scores_value', 'price']].corr(), annot=True, cmap= 'coolwarm', linewidths=0.5, vmax= 1, vmin= -1)
# Out:
# <Axes: >

# %% [markdown]
# Podemos notar que no hay una correlación significativa entre las puntuaciones de las reseñas y el precio de renta de los alojamientos. Los coeficientes de correlación, que están por debajo de 0.01, sugieren una relación muy débil o inexistente.
#
# Esta falta de correlación puede tener varias explicaciones:
#
# - **Diversidad de preferencias de los huéspedes:**
#
#     Los huéspedes pueden valorar aspectos diferentes al momento de dejar una reseña, como la limpieza, la comodidad, la ubicación o la atención del anfitrión. Estos aspectos pueden no estar directamente relacionados con el precio del alojamiento.
#
# - **Variedad en la oferta de alojamientos:**
#
#     El mercado de Airbnb ofrece una amplia gama de alojamientos con diferentes características y precios. Esto significa que las puntuaciones de las reseñas pueden reflejar la calidad y experiencia de cada alojamiento de manera independiente al precio.
#
# - **Expectativas versus realidad:**
#
#     Las expectativas de los huéspedes pueden influir en sus reseñas, independientemente del precio.  Si los huéspedes pagan menos por un alojamiento de Airbnb, es probable que tengan expectativas más bajas en términos de comodidades, servicios y calidad en comparación con alojamientos más caros. Cuando estas expectativas se cumplen o superan, los huéspedes suelen quedar más satisfechos y es probable que otorguen una calificación más alta. Entonces, un alojamiento económico que cumple con las expectativas puede recibir una alta puntuación, mientras que uno costoso, con altas expectativas, que no cumple puede recibir una calificación mas baja.
#
# - **Factores subjetivos:**
#
#     Las puntuaciones de las reseñas también pueden estar influenciadas por factores subjetivos y experiencias personales de los huéspedes, lo que puede variar ampliamente y no estar relacionado directamente con el precio.

# %% [markdown]
# ##### **Influencia del número de reseñas en el precio.**

# %% [markdown]
# Destaca que el número de reseñas parece tener una influencia (débil) negativa en el precio. Esta observación podría sugerir una relación casi nula o un poco inversa entre la cantidad de reseñas recibidas por un alojamiento y el precio que se cobra por él. Podemos visualizar esta relación mediante un scatter plot, donde podemos observar la relación y dirección entre estas variables.

# %%
sns.scatterplot(y= df['price'][df['price']<10000], x= df['number_of_reviews'][df['price']<10000])
sns.regplot(y= df['price'][df['price']<10000], x= df['number_of_reviews'][df['price']<10000], scatter=False, line_kws={"color": "black"})
# Out:
# <Axes: xlabel='number_of_reviews', ylabel='price'>

# %% [markdown]
# Observamos que la cantidad de reseñas en relación con el precio muestra una correlación negativa muy débil. Podemos destacar algunas razones por las cuales la cantidad de reseñas podría no influir o podría influir negativamente en los precios de alojamientos de Airbnb:
#
# - **Sensibilidad al precio:**
#
#     Los alojamientos con más reviews podrían ser más sensibles a cambios en los precios debido a la mayor visibilidad y exposición en la plataforma. Esto podría llevar a ajustes de precios más frecuentes para atraer y retener huéspedes.
#
# - **Competencia basada en precios:**
#
#     En un mercado donde los precios son un factor determinante para los huéspedes, los alojamientos con más reviews podrían enfrentar una competencia más intensa en términos de precios, lo que podría conducir a una presión a la baja en los precios. Los anfitriones saben que cada noche que su propiedad permanece vacía no obtienen ingresos, por lo tanto, es probable que cobren precios bajos para tener mas reservaciones lo que conlleva mas reseñas.
#
# - **Efecto de la reputación del alojamiento:**
#
#     Si los alojamientos tienen una cantidad significativa de reviews negativos, esto puede afectar su reputación y, por lo tanto, su capacidad para mantener precios más altos en comparación con alojamientos con menos cantidad de reseñas pero mejores calificaciones. En otras palabras, cuando hay más reseñas, los potenciales huéspedes tienen más información sobre el alojamiento, lo que reduce la capacidad del anfitrión para fijar un precio más alto sin proporcionar una justificación clara o evidencia de una calidad o valor adicional, como mejoras significativas en las instalaciones o servicios.
#
# - **Influencia de la demanda:**
#
#     Otra posible explicación es que sea un resultado de la demanda, donde listados con menor precio se reservan más frecuentemente y por tanto tienen mayores reseñas. Los alojamientos con precios más bajos tienden a ser más atractivos para un segmento de la demanda que busca opciones económicas. Esto puede llevar a una mayor cantidad de reservas y, por lo tanto, más reseñas en comparación con alojamientos de precios más altos.

# %% [markdown]
# ## **8. Summary Analysis.**

# %% [markdown]
# ### **Precio por Noche Promedio en la Ciudad de México.**

# %% [markdown]
# - **Distribución de los precios en la Ciudad de México:**
#
#     El precio medio por noche en la Ciudad de México es de $1,401.98 pesos mexicanos, mientras que la mediana se sitúa alrededor de $1,000 pesos mexicanos. Estos datos reflejaron la centralidad de los precios, indicando que el 50% de los listados se encuentran por debajo de los $1,000. Asimismo, el 75% de los alojamientos tienen precios inferiores a $1,597.00. Además, aproximadamente la mitad de los alojamientos tienen un rango de precios por noche entre $639.75 y $1,597.00.
#
#
# - **Interpretación de la variabilidad en los precios:**
#
#     La alta desviación estándar de aproximadamente $1,669.41 sugirió una amplia variabilidad en los precios de alojamientos. Se determinó que hay una considerable diversidad de precios, desde precios muy bajos hasta precios muy altos, lo que refleja la variedad de opciones disponibles en el mercado de Airbnb en la Ciudad de México.
#     La distribución sesgada hacia la derecha, con la mayoría de los precios concentrados en el rango más bajo y algunos precios extremadamente altos, es característica de muchos mercados, incluido el de alojamientos. Esto refleja la naturaleza diversa y heterogénea de los precios, donde la mayoría de las opciones de alojamiento son asequibles pero también existen opciones de lujo o exclusivas.
#
# - **Impacto de los precios extremos:**
#
#     Los precios extremos, como el máximo de $47,719.00, pueden influir en la percepción general de los precios en el mercado. Aunque estos precios son poco frecuentes, pueden tener un impacto significativo en la imagen general de la oferta de alojamientos, especialmente en términos de percepción de exclusividad o lujo.
#     Es importante considerar cómo estos precios extremos pueden afectar la estrategia de precios de los anfitriones y las expectativas de los huéspedes. Por ejemplo, los precios extremadamente altos podrían estar asociados con características excepcionales en los alojamientos, lo que puede atraer a un segmento específico de clientes dispuestos a pagar por experiencias premium.

# %% [markdown]
# ### **Distribución de Alojamientos en la Ciudad de México.**

# %% [markdown]
# - **Cuauhtémoc lidera en cantidad de alojamientos:**
#
#     Cuauhtémoc es la alcaldía más representada en cuanto a cantidad de alojamientos, con un total de 7,994 listados, lo que equivale al 49.7% de todos los listados analizados. Esto indica que Cuauhtémoc es una zona muy popular tanto para anfitriones como para huéspedes en Airbnb en la Ciudad de México.
#
# - **Miguel Hidalgo y Benito Juárez también son populares:**
#
#     Miguel Hidalgo y Benito Juárez siguen a Cuauhtémoc en términos de cantidad de alojamientos, con el 17.9% y el 11.4% de los listados respectivamente. Estas alcaldías también son áreas populares para la oferta y demanda de alojamientos en Airbnb.
#
# - **Distribución variada en otras alcaldías:**
#
#     Otras alcaldías como Coyoacán, Álvaro Obregón, Venustiano Carranza, Tlalpan, entre otras, también tienen una presencia significativa de alojamientos, aunque en menor cantidad en comparación con las tres primeras alcaldías mencionadas. Esto muestra una distribución variada de la oferta de alojamientos en diferentes áreas de la Ciudad de México.
#
# - **Patrones de preferencia y oferta:**
#
#     La distribución por alcaldía proporcionó información sobre patrones de preferencia y oferta en diferentes zonas de la ciudad. Por ejemplo, la concentración de alojamientos en Cuauhtémoc puede indicar una alta demanda por parte de los huéspedes debido a su ubicación céntrica y acceso a atracciones turísticas, mientras que la presencia significativa en Miguel Hidalgo y Benito Juárez también refleja áreas populares y atractivas para los viajeros.

# %% [markdown]
# ### **Influencia de las características del anfitrion en el precio.**

# %% [markdown]
# - **Tiempo de respuesta del anfitrión:**
#
#     Los alojamientos cuya información sobre el tiempo de respuesta es dentro de una hora tienen el precio medio más alto, lo que sugiere que los huéspedes pueden valorar la prontitud en las respuestas de los anfitriones y estar dispuestos a pagar más por esa atención rápida. Por otro lado, los alojamientos con respuestas dentro de pocas horas tienen el segundo precio medio más alto, lo que resalta la importancia de la velocidad de respuesta para los huéspedes que buscan una comunicación fluida y eficiente.
#
# - **Estado de superhost del anfitrión:**
#
#     Los alojamientos de anfitriones con la distinción de superhost tienen un precio medio más alto en comparación con aquellos sin esta distinción, posiblemente debido a la reputación y confianza asociadas con los superanfitriones. Esto puede influir en la percepción de calidad y confiabilidad por parte de los huéspedes.
#
# - **Presencia de foto de perfil del anfitrión:**
#
#     Los alojamientos con anfitriones que tienen una foto de perfil tienen un precio medio más alto en comparación con aquellos sin foto de perfil. Esto sugiere que la presencia de una foto de perfil puede estar asociada con factores como confianza, transparencia y hospitalidad, lo que puede influir en la percepción de calidad y, por lo tanto, en los precios.
#
# - **Verificación de identidad del anfitrión:**
#
#     Existe una interesante tendencia donde los alojamientos sin verificación de identidad tienen un precio medio más alto en comparación con aquellos con verificación. Esto puede sugerir que los huéspedes están dispuestos a pagar más por ciertos tipos de alojamientos a pesar de la falta de verificación de identidad del anfitrión, posiblemente debido a factores como exclusividad y calidad percibida.

# %% [markdown]
# ### **Distribución de Alojamientos por Alcaldía y Tipo de Alojamiento.**

# %% [markdown]
# - **Preferencias de alojamientos enteros o privados:**
#
#   Cuauhtémoc, la alcaldía con mayor número de alojamientos, mostró una alta preferencia por alojamientos del tipo Entire home/apt (78.30%) y Private room (20.5%), con una menor preferencia por alojamientos Shared room (1.03%) y Hotel room (0.15%). Esto sugiere que los huéspedes y anfitriones en Cuauhtémoc prefieren alojamientos completos o habitaciones privadas sobre alojamientos compartidos o de tipo hotelero. En Miguel Hidalgo, la preferencia fue similar, con una alta proporción de Entire home/apt (78.22%) y Private room (21.36%).
#
#   Benito Juárez, la tercera alcaldía con mayor presencia de alojamientos, también mostró una preferencia significativa por Entire home/apt (65.27%) y Private room (34.18%), con una proporción menor de Hotel room (0.22%) y Shared room (0.33%).
#
#   Otras alcaldías como Coyoacán, Álvaro Obregón, Venustiano Carranza, entre otras, muestran preferencias similares, con una clara preferencia por alojamientos completos o habitaciones privadas sobre alojamientos compartidos o de tipo hotelero.
#
# - **Diversidad de oferta y enfoque en ciertos tipos de alojamiento:**
#
#   Cuauhtémoc, Miguel Hidalgo y Benito Juárez tienen una mayor diversidad en la oferta de alojamientos, ya que se encuentran representados todos los tipos de alojamiento en mayor proporción que en otras alcaldías.
#
#   La mayoría de las alcaldías muestran un enfoque más marcado en alojamientos del tipo Entire home/apt y Private room en comparación con Hotel room y Shared room. Esto sugiere una demanda predominante por alojamientos completos o habitaciones privadas en Airbnb en la Ciudad de México.
#
#   Tlalpan es una de las pocas alcaldías donde las habitaciones privadas (Private room) ocupan una mayor proporción que los alojamientos enteros (Entire home/apt), lo que puede indicar una oferta específica para viajeros que prefieren espacios más íntimos y económicos.

# %% [markdown]
# ### **Precio Medio por Alcaldía.**

# %% [markdown]
# - **Variación del rango de precios por alcaldía:**
#
#     El análisis reveló una variación significativa en el rango de precios entre diferentes alcaldías en la Ciudad de México, con Miguel Hidalgo y Cuauhtémoc entre las áreas más caras para alojamientos, mientras que Iztapalapa y Tláhuac ofrecen las opciones más económicas.
#
# - **Impacto de la centralidad de la ciudad en los Precios:**
#
#     Alcaldías como Miguel Hidalgo y Cuauhtémoc, que abarcan las zonas centrales de la ciudad, tienden a tener precios de alojamiento más altos, posiblemente debido a su proximidad al centro de la ciudad, a atracciones principales y centros de negocios.
#
# - **Consideraciones de presupuesto:**
#
#     Los viajeros con presupuestos limitados pueden encontrar atractivas las opciones en Gustavo A. Madero, Iztapalapa y Tláhuac, ya que estas alcaldías ofrecen los precios promedio más bajos para alojamientos, siendo opciones adecuadas para huéspedes conscientes del costo o con un presupuesto limitado.
#
#     Miguel Hidalgo y Cuauhtémoc son alcaldías con precios más altos, pero también ofrecen una amplia gama de servicios y atracciones turísticas, lo que puede justificar el costo adicional para algunos viajeros.
#
# - **Segmentación del mercado:**
#
#     Comprender la distribución de precios por alcaldías ayuda en la segmentación del mercado, permitiendo a los anfitriones dirigirse a diferentes segmentos de viajeros según sus preferencias de presupuesto y geográficas dentro de la Ciudad de México.
#
#     En áreas como Miguel Hidalgo y Cuauhtémoc, donde los precios promedio son más altos, los anfitriones pueden considerar ofrecer servicios adicionales o experiencias personalizadas para justificar los precios y atraer a huéspedes dispuestos a pagar más. En alcaldías con precios más bajos como Iztapalapa y Tláhuac, es importante destacar la relación calidad-precio de los alojamientos y resaltar las ventajas de la ubicación para atraer a huéspedes con presupuestos ajustados.

# %% [markdown]
# ### **Precio Medio por Alcaldía y Tipo de Alojamiento.**

# %% [markdown]
# - **Optimización del presupuesto y elección del tipo de alojamiento:**
#
#     Los huéspedes pueden encontrar opciones atractivas según sus presupuestos. Considerando la relación precio-tipo de alojamiento, áreas como Iztapalapa y Tláhuac ofrecen opciones más económicas, especialmente en la categoría de Entire home/apt. Estas alcaldías son ideales para huéspedes que buscan alojamientos asequibles sin comprometer la privacidad y comodidad.
#
#     Para aquellos que buscan opciones de alta gama, las alcaldías de Cuauhtémoc y Miguel Hidalgo ofrecen variedad en tipos de alojamiento como Entire home/apt y Hotel room, con precios más altos pero con servicios y comodidades adicionales.
#
#     En áreas como Coyoacán y Cuajimalpa de Morelos, los precios de Hotel room son notablemente altos, alcanzando un promedio de $2,836.00 y $2,123.00. Esto puede indicar experiencias exclusivas o habitaciones de lujo para quienes buscan opciones más premium. Es importante tener en cuenta que estos datos están basados en un solo alojamiento de este tipo en cada una de estas áreas, por lo tanto, no necesariamente podrían representar la generalidad de los precios en estas áreas para este tipo de alojamiento.
#
#     En áreas con precios más bajos para tipos de alojamiento como Private room y Shared room, como en Gustavo A. Madero y Tláhuac, los turistas pueden encontrar opciones económicas para estadías cortas o viajes de trabajo con presupuestos ajustados, compartiendo alojamiento con otros huéspedes.
#
# - **Estrategia de precios de los anfitriones:**
#
#     Los anfitriones pueden ajustar sus estrategias de precios según el tipo de alojamiento y la ubicación. Por ejemplo, anfitriones con alojamientos en áreas como Cuauhtémoc, Benito Juárez y Miguel Hidalgo pueden beneficiarse de la diversidad de oferta en estas áreas, para atraer a diferentes segmentos de huéspedes y maximizar sus ingresos.
#
#     Los precios reflejan la dinámica de demanda y oferta por tipo de alojamiento en cada alcaldía. Los anfitriones pueden adaptar su oferta según las preferencias de los huéspedes en cada área.
#
# - **Oportunidades de inversión:**
#
#     El análisis reveló oportunidades de inversión según la demanda y oferta de tipos de alojamiento en diferentes alcaldías. Para inversores o anfitriones que buscan invertir en propiedades de Airbnb, áreas como Miguel Hidalgo y Cuauhtémoc presentan potencial para obtener ingresos de alquiler más altos debido a sus precios promedio más elevados en los diferentes tipos de alojamiento, mientras que áreas como Iztapalapa y Tláhuac pueden ofrecer oportunidades para inversiones inmobiliarias accesibles.
#
#     Las alcaldías con precios más altos pueden ser áreas atractivas para invertir en propiedades de Airbnb, especialmente considerando la demanda de viajeros que buscan comodidad y proximidad a atracciones turísticas o punto de mayor interés en la ciudad. Sin embargo, las alcaldías con precios más bajos también representan oportunidades de inversión, especialmente para aquellos que desean diversificar su cartera y ofrecer opciones más económicas en el mercado de alojamientos temporales.

# %% [markdown]
# ### **Impacto de las características del alojamiento en el precio.**

# %% [markdown]
# - **Las características de los alojamientos que mas influyen en el precio:**
#
#     El análisis mostró que variables como el número de habitaciones, baños, capacidad de huéspedes y camas disponibles tienen correlaciones positivas significativas con el precio de los alojamientos. Esto sugiere que estas características influyen en gran medida en la determinación de precios en el mercado de alojamientos de Airbnb.
#
#     Anfitriones pueden considerar estas características al fijar precios, ya que propiedades con más habitaciones, baños, capacidad para más huéspedes y camas tienden a tener precios más altos. Esta relación refleja la percepción de valor que los huéspedes atribuyen a propiedades más grandes y con más comodidades.
#
# - **Experiencia y comodidad para los huéspedes:**
#
#     La correlación positiva entre estas características y el precio indica que los huéspedes valoran la capacidad de alojamiento y las comodidades adicionales. Esto sugiere que los anfitriones pueden destacar estas características al comercializar sus alojamientos, ya que pueden atraer a huéspedes dispuestos a pagar más por una experiencia cómoda y espaciosa.
#
#     Las propiedades que pueden acomodar a más personas, ofrecer más habitaciones y baños, y disponer de camas adicionales pueden ser percibidas como más atractivas para grupos grandes o familias, lo que podría justificar precios más altos.
#
# - **Consideraciones para inversionistas:**
#
#     Los inversionistas interesados en el mercado de Airbnb en la Ciudad de México pueden tomar en cuenta estas correlaciones al evaluar propiedades para inversión. Propiedades con características que correlacionan positivamente con precios más altos pueden ser consideradas como inversiones potencialmente rentables, ya que tienen mayor potencial de generar ingresos por alquiler. La capacidad de alojamiento, la distribución de habitaciones y baños, la disponibilidad de camas, asi como la privacidad de los alojamientos pueden ser factores clave a considerar al identificar oportunidades de inversión en el mercado de alojamientos de Airbnb.

# %% [markdown]
# ### **Impacto de las puntuaciones de las reseñas en el precio.**

# %% [markdown]
# - **Sin correlación significativa con el precio.**
#
#     El análisis mostró que no hay una correlación significativa o hay una relación inexistente entre las puntuaciones de las reseñas y el precio de renta de los alojamientos. Esta falta de correlación puede deberse a varios factores.
#
# - **Diversidad de preferencias de los huéspedes:**
#
#     Las puntuaciones de las reseñas pueden reflejar aspectos diversos que los huéspedes valoran al evaluar un alojamiento, como la limpieza, la ubicación, la comunicación con el anfitrión, entre otros. Estos aspectos pueden no estar directamente relacionados con el precio del alojamiento, lo que explica la falta de correlación significativa encontrada en el análisis.
#
#     Anfitriones pueden considerar estos aspectos al mejorar la experiencia para sus huéspedes, ya que una alta calidad en estos aspectos puede generar buenas reseñas y experiencias positivas, independientemente del precio del alojamiento.
#
# - **Variedad en la oferta de alojamientos:**
#
#     El amplio rango de alojamientos disponibles en Airbnb, con diferentes características y precios, significa que las puntuaciones de las reseñas pueden variar ampliamente y no necesariamente estar ligadas al precio. Los huéspedes pueden evaluar cada alojamiento de manera independiente en función de su experiencia, calidad y cumplimiento de expectativas.
#
# - **Expectativas versus realidad:**
#
#     Las expectativas de los huéspedes pueden influir significativamente en sus puntuaciones de reseñas. Si los huéspedes tienen expectativas alineadas con el precio que pagan por el alojamiento, es más probable que otorguen puntuaciones más altas si sus expectativas se cumplen o superan.
#
#     Un alojamiento económico que cumple con las expectativas puede recibir una alta puntuación, mientras que uno costoso, con altas expectativas, que no cumple puede recibir una calificación mas baja.
#
#     Anfitriones pueden trabajar en comunicar claramente las características y servicios ofrecidos en sus alojamientos para alinear las expectativas de los huéspedes y fomentar experiencias positivas que se reflejen en buenas puntuaciones de reseñas.

# %% [markdown]
# ### **Impacto del número de reseñas en el precio.**

# %% [markdown]
# - **Correlación muy débil con el precio:**
#
#     El análisis mostró que hay una correlación negativa muy débil entre el número de reseñas de un alojamiento y el precio de renta. Hay algunas razones por las cuales el número de reseñas de los alojamientos podría influir negativamente o podría no influir en el precio de renta.
#
# - **Sensibilidad al precio:**
#
#     Los alojamientos con una mayor cantidad de reseñas pueden ser más sensibles a cambios en los precios. Esto se debe a que tienen una mayor visibilidad y exposición en la plataforma, lo que los hace más susceptibles a ajustes de precios para atraer y retener huéspedes.
#
# - **Competencia basada en precios:**
#
#     En un mercado donde el precio es un factor crucial para los huéspedes, los alojamientos con muchas reseñas pueden enfrentar una competencia más intensa en términos de precios. Esto puede resultar en una presión a la baja en los precios, ya que los anfitriones podrían ajustar sus tarifas para mantener su atractivo y competir efectivamente con otros listados.
#
# - **Efecto de la reputación del alojamiento:**
#
#     La cantidad de reseñas puede afectar la reputación del alojamiento. Si un alojamiento tiene muchas reseñas negativas, esto puede influir negativamente en su capacidad para mantener precios más altos. Los huéspedes confían en las reseñas para tomar decisiones informadas, por lo que una gran cantidad de reseñas negativas puede disuadir a los huéspedes y limitar la capacidad del anfitrión para justificar precios más elevados.
#
# - **Influencia de la demanda:**
#
#     La posible relación inversa entre el número de reseñas y el precio puede ser un reflejo de la demanda y la atracción de alojamientos con precios más bajos. Los listados con tarifas más asequibles tienden a atraer a un segmento de la demanda que busca opciones económicas, lo que puede generar más reservas y, por lo tanto, más reseñas en comparación con alojamientos de precios más altos o mas exclusivos.

# %% [markdown]
# ### **Factores clave que influyen en el precio de renta de los alojamientos.**

# %% [markdown]
# Se identificaron tendencias y factores clave que tienen una mayor influencia en el precio de los alojamientos en el mercado de Airbnb en la Ciudad de Méixco.
#
# - **Tiempo de respuesta del anfitrión:**
#
#     Se observó que tiempos de respuesta rápidos por parte del anfitrión están asociado con precios ligeramente más altos. Alojamientos con prontitud de respuesta parecen tener una mayor valoración.
#
# - **Distinción de Superhost:**
#
#     Los alojamientos con la distinción de Superhost tienden a tener precios más elevados posiblemente debido a la reputación y calidad de servicio que este reconocimiento conlleva.
#
# - **Presencia de foto de perfil del anfitrión:**
#
#     La presencia de una foto de perfil del anfitrión también se relacionó con precios más altos, esta tendencia podría estar relacionada a que la presencia de una foto de perfil transmite confianza y profesionalismo a los posibles huéspedes.
#
# - **Tipo de alojamiento:**
#
#     Diferentes tipos de alojamientos, como apartamentos enteros, habitaciones privadas o alojamientos compartidos, tienen impactos distintos en los precios debido a sus características y comodidades únicas. Se determinó que los alojamientos enteros y los alojamientos tipo hotel tienden a tener precios de renta mas altos, alojarse en un espacio entenro o en un hotel tiende a ser mas costoso que compartir espacio con otros huéspedes.
#
# - **Alcaldías con mayor cercanía a puntos de interés:**
#
#     Se observó que las alcaldías que están más cerca del centro, zonas turísticas y centros de negocios tienden a  tener precios más altos debido a su conveniencia, accesibilidad y proximidad a los puntos de mayor interés en la Ciudad de México.
#
# - **Número de habitaciones, baños, camas y capacidad de huéspedes:**
#
#     Se determinó que, el número de habitaciones, baños, camas y de huespedes permitidos, son características que tienen una influencia significativa en los precios de renta. Alojamientos con más comodidades, espacio y capacidad para más huéspedes tienden a tener precios más elevados.

# %% [markdown]
# ## **9. Conclusion**

# %% [markdown]
# El análisis de datos de alojamientos de Airbnb en la Ciudad de México ha proporcionado una visión y comprensión de las tendencias y factores clave que influyen en el mercado de Airbnb. A través de este proyecto, se han identificado tendencias y patrones significativos y se han extraído valiosos insights que puedan ser útiles tanto a propietarios de alojamientos como a posibles huéspedes y otras partes interesadas en el mercado de alojamientos de Airbnb en la Ciudad de México.
#
# Se ha observado que factores como el tiempo de respuesta del anfitrión, la distinción de Superhost, la presencia de foto de perfil del anfitrión, el tipo de alojamiento y la ubicación geográfica tienen una relación con los precios de los alojamientos. Al mismo tiempo, variables como el número de habitaciones, baños, camas y capacidad de huéspedes son características que tiene una mayor influencia en los precios y en la percepción de valor por parte de los usuarios.
#
# Este proyecto no solo ha permitido comprender la dinámica del mercado de alojamientos en la Ciudad de México, sino que también ha brindado información útil para la toma de decisiones estratégicas. Propietarios de alojamientos pueden ajustar sus precios y servicios considerando estos factores clave, mientras que los huéspedes pueden tomar decisiones más informadas al elegir alojamientos que se ajusten a sus necesidades, presupuesto y expectativas.
#
# En resumen, este análisis de datos ha contribuido a la comprensión del mercado de alojamientos de Airbnb en la Ciudad de México, proporcionando una base para futuros análisis mas avanzados y acciones orientadas a mejorar la experiencia tanto para anfitriones como para huéspedes.
